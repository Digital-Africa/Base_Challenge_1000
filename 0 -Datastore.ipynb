# %%
from google.cloud import datastore
import datetime

def update_document():
    city_ref = db.collection(u'cities').document(u'BJ')

    city_ref.set({
        u'capital': True
    }, merge=True)
    
def create_collection():
    return None

    
    
def run_execute(GOOGLE_APPLICATION_CREDENTIALS):

    # Explicitly use service account credentials by specifying the private key
    # file.
    db = datastore.Client.from_service_account_json(
        GOOGLE_APPLICATION_CREDENTIALS)
    create_document(db)

# %%
from google.cloud import datastore
import datetime
import pandas
GOOGLE_APPLICATION_CREDENTIALS="/Users/Shared/digital-africa/web-services-d4-digital-africa-2eb794c55b04.json"
client = datastore.Client.from_service_account_json(
        GOOGLE_APPLICATION_CREDENTIALS)

# %%
def update_record(client, task_id):
    with client.transaction():
        key = client.key('Task', task_id)
        task = client.get(key)

        if not task:
            raise ValueError(
                'Task {} does not exist.'.format(task_id))

        task['done'] = True

        client.put(task)
# Out:
# --------------------------------------------
# ValueError Traceback (most recent call last)
# <ipython-input-50-89f985940b3b> in <module>
#      11
#      12         client.put(task)
# ---> 13 mark_done(client, 5634161670881280)
#
# <ipython-input-41-97e3be2bf297> in mark_done(client, task_id)
#       6         if not task:
#       7             raise ValueError(
# ----> 8                 'Task {} does not exist.'.format(task_id))
#       9
#      10         task['done'] = True
#
# ValueError: Task 5634161670881280 does not exist.

# %%
def delete_task(client, task_id):
    key = client.key('Task', task_id)
    client.delete(key)

# %%
def list_tasks(client):
    query = client.query(kind='Task')
    #query.order = ['created']

    return list(query.fetch())
list_tasks(client)
# Out:
# []

# %%
import chalenge1000


def chunkIt(seq, num):
    avg = len(seq) / float(num)
    out = []
    last = 0.0

    while last < len(seq):
        out.append(seq[int(last):int(last + avg)])
        last += avg
    return out


Chalenge = chalenge1000.Native()
descriptions = Chalenge.descriptions
data = descriptions[['nom_struc','prez_struc', 'prez_produit_struc']].reset_index().to_dict(orient = 'records')
data = chunkIt(data, 10)
data_test = data[0]
#data[0]

# %%
def add_data(client, data):
    key = client.key('SU_challenge1000')

    task = datastore.Entity(
        key, exclude_from_indexes=['prez_struc', 'prez_produit_struc'])
    #task = datastore.Entity(key)
    #data.update({'created': datetime.datetime.utcnow()})
    task.update(data)

    client.put(task)

    return task.key
#print(data_test)
add_data(client, data_test[0])
# Out:
# <Key('SU_challenge1000', 5631671361601536), project=web-services-d4-digital-africa>

# %%
data_test[0]
# Out:
# {'key_main': 'http://seneyakaare.com_ndiaye_diariyata',
#  'nom_struc': 'SENEYAKAARE',
#  'prez_struc': "Startup santé d'aide au diagnostic et à la prise en charge de pathologie chronique en passant également par l'éducation thérapeutique",
#  'prez_produit_struc': "SEN'Diabète : plateforme médicale de gestion du diabète avec téléconsultation, gestion à distance des données patients."}

# %%
for chunk in data:
    batch = client.batch()
    with batch:
        for element in chunk:
            add_data(client, element)

# %%
len(data[0])
# Out:
# 344

# %%
def list_tasks(client):
    query = client.query(kind='SU_challenge1000')
    #query.order = ['created']
    return list(query.fetch())

SU = list_tasks(client)
len(SU)
# Out:
# 1

# %%
e = client.query(kind='SU_challenge1000').fetch()
[client.delete(k.key) for k in list(e)]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
complete_key = client.key('Task', 'sample_task')

task = datastore.Entity(key=complete_key)

task.update({
    'category': 'Personal',
    'done': False,
    'priority': 4,
    'description': 'Learn Cloud Datastore'
})

client.put(task)

# %%
def add_data(client, data):
    key = client.key('SU_challenge1000',data['key_main'])

    task = datastore.Entity(
        key, exclude_from_indexes=['prez_struc', 'prez_produit_struc'])
    #task = datastore.Entity(key)
    #data.update({'created': datetime.datetime.utcnow()})
    task.update(data)

    client.put(task)

    return task.key

def update_record(client,entity_name, task_id):
    with client.transaction():
        key = client.key(entity_name, task_id)
        task = client.get(key)

        if not task:
            raise ValueError(
                'Task {} does not exist.'.format(task_id))

        task['Agriculture'] = True

        client.put(task)

# %%
#print(data_test)
#data_test[0]['key_main']
add_data(client, data_test[0])
# Out:
# <Key('SU_challenge1000', 'http://seneyakaare.com_ndiaye_diariyata'), project=web-services-d4-digital-africa>

# %%
e = client.query(kind='SU_challenge1000').fetch()
[k.key for k in list(e)]
# Out:
# [<Key('SU_challenge1000', 'http://seneyakaare.com_ndiaye_diariyata'), project=web-services-d4-digital-africa>]

# %%
update_record(client, 'SU_challenge1000', 'http://seneyakaare.com_ndiaye_diariyata')

# %%
type(SU[0])
# Out:
# google.cloud.datastore.entity.Entity

# %%
SU[0].__dir__()
records = pandas.DataFrame(list(SU[0].values())).transpose()
records.columns = list(SU[0].keys())
records.set_index('key_main')
# Out:
#                                                                         prez_produit_struc  \
# key_main
# http://seneyakaare.com_ndiaye_diariyata  SEN'Diabète : plateforme médicale de gestion d...
#
#                                         Agriculture  \
# key_main
# http://seneyakaare.com_ndiaye_diariyata        True
#
#                                                                                 prez_struc  \
# key_main
# http://seneyakaare.com_ndiaye_diariyata  Startup santé d'aide au diagnostic et à la pri...
#
#                                            nom_struc
# key_main
# http://seneyakaare.com_ndiaye_diariyata  SENEYAKAARE

# %%
dict(SU[0].items())
# Out:
# {'prez_produit_struc': "SEN'Diabète : plateforme médicale de gestion du diabète avec téléconsultation, gestion à distance des données patients.",
#  'Agriculture': True,
#  'key_main': 'http://seneyakaare.com_ndiaye_diariyata',
#  'prez_struc': "Startup santé d'aide au diagnostic et à la prise en charge de pathologie chronique en passant également par l'éducation thérapeutique",
#  'nom_struc': 'SENEYAKAARE'}

# %%
list(SU[0].keys())
# Out:
# ['prez_produit_struc', 'Agriculture', 'key_main', 'prez_struc', 'nom_struc']

# %%
list(SU[0].values())
# Out:
# ["SEN'Diabète : plateforme médicale de gestion du diabète avec téléconsultation, gestion à distance des données patients.",
#  True,
#  'http://seneyakaare.com_ndiaye_diariyata',
#  "Startup santé d'aide au diagnostic et à la prise en charge de pathologie chronique en passant également par l'éducation thérapeutique",
#  'SENEYAKAARE']

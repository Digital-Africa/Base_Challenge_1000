# %%
import chalenge1000
import model_lib
import collections
from IPython.display import display, HTML
import pandas

Chalenge = chalenge1000.Native()
df = Chalenge.X

# %%
def vocab(element):
    if type(element) == str:
        return ' '.join(set(element.split(' ')))
    else:
        return ''

def _agriculture__(element):
    if element in agriculture:
        return True
    else:
        return False
    
col_count = lambda x: ' '.join([a for a,b in collections.Counter(x.split()).most_common(10000)])
lemm = lambda x: model_lib.Lemm(x,file = 'stopwords_agri.txt').X

def df_fmt(df):
    df['corpus'] = df.join(Chalenge.descriptions_trad)[['prez_struc','prez_produit_struc']].agg(sum, axis = 1)
    df['type'] = df['corpus'].map(type)
    df['corpus'] = df['corpus'].map(vocab)
    df['corpus_lemm'] = df['corpus'].map(lemm)
    df['collection_counter'] = df['corpus_lemm'].map(col_count)
    agr = {e for e in df['cat_autre_struc'].dropna().values.tolist() if 'agr' in e}
    alim = {e for e in df['cat_autre_struc'].dropna().values.tolist() if 'alim' in e}
    agriculture = alim.union(agr)
    #df = df[df['type'] ==str]
    return df

# %%
df = df_fmt(df)

text_corpus = df[(df['categorie'].isin(['agriculture','media'])) & (df['type'] ==str)]['collection_counter']
text_corpus_label = df[df['categorie'].isin(['agriculture','media']) & (df['type'] ==str)][['categorie','collection_counter']]

# %%
#model = model_lib.Models(n_components = n_components, n_top_words =n_top_words, n_features = n_features)
def run_model_lda(model_parameters,text_corpus):
    def get_topic(e):
        if e >0:
            return 'agriculture'
        if e<0:
            return 'media'
    
    def true_positve(a,b):
        if a == b:
            return 1
        else:
            return 0
    model = model_lib.Models(**model_parameters)

    models = model.run_model_LDA(text_corpus.values.tolist())

    predict = pandas.DataFrame(model.reverse_lda(text_corpus.values.tolist(), models) , index =text_corpus.index)
    #display(predict)

    predict = predict.join(df['categorie'])
    predict[0] = predict[0]*100
    predict[1] = predict[1]*100
    predict['topic'] = predict[0]-predict[1]
    #display(predict)

    predict['predict_label'] = predict['topic'].map(get_topic)
    #display(predict)

    predict['classification_kpi'] = predict.apply(lambda x: true_positve(x['categorie'],x['predict_label']), axis= 1)
    #display(predict)

    agri = predict[predict['categorie'] == 'agriculture']
    print(model_parameters)
    print('precision {}'.format(agri['classification_kpi'].sum()/len(agri)*100))
    model_parameters.update({'precision':agri['classification_kpi'].sum()/len(agri)*100, 'vocabulaire': models['LDA']['feature_names']})
    errors = agri[agri['classification_kpi'] == 0].sort_values('topic')
    collections.Counter(' '.join(errors.join(text_corpus)['collection_counter'].values.tolist()).split()).most_common(10)
    return model_parameters

# %%
list_model_parameters_prior = [{'n_components' : 2, 'n_top_words' : 20, 'n_features' : 20000, 'doc_topic_prior':alpha} for alpha in range(1,100,1)]

list_run = []
for model_parameters in list_model_parameters_prior:
    list_run.append(run_model_lda(model_parameters,text_corpus))
result_priors = pandas.DataFrame(list_run).sort_values('precision', ascending = False)
# Out:
# Extracting tf features for LDA...
# done in 0.143s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.579s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food service farmer local farm agriculture young woman sustainable rural develop management order
# Topic #1: zou product breed en farmer promoter market fish régional creation feed entrepreneures agricoles recreation conseil production collines ponds tilapia presentation
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 1}
# precision 97.41007194244604
# Extracting tf features for LDA...
# done in 0.071s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.848s.
#
# Topics in LDA model:
# Topic #0: product market make production agricultural create produce food service farmer local agriculture farm young sustainable rural develop management woman order
# Topic #1: product production market oil fruit create palm produce food agricultural juice zou transformation nut soap sugar local woman material farmer
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 2}
# precision 87.05035971223022
# Extracting tf features for LDA...
# done in 0.068s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.919s.
#
# Topics in LDA model:
# Topic #0: product make market production agricultural service create food farmer produce agriculture local farm sustainable young rural management develop order woman
# Topic #1: product market production create produce food fruit agricultural make local oil woman farm farmer material natural palm plant juice transformation
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 3}
# precision 71.22302158273382
# Extracting tf features for LDA...
# done in 0.067s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.865s.
#
# Topics in LDA model:
# Topic #0: product make market production service agricultural food create farmer produce agriculture sustainable local farm young rural management order develop social
# Topic #1: product market production create produce agricultural food make local fruit farm farmer woman oil young plant material agriculture natural develop
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 4}
# precision 59.280575539568346
# Extracting tf features for LDA...
# done in 0.110s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 2.287s.
#
# Topics in LDA model:
# Topic #0: make product service production market agricultural food create farmer produce agriculture sustainable local young rural farm order management develop access
# Topic #1: product market production create produce agricultural food make local farm farmer fruit woman agriculture young plant develop oil material service
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 5}
# precision 52.94964028776978
# Extracting tf features for LDA...
# done in 0.072s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 3.106s.
#
# Topics in LDA model:
# Topic #0: make product production service market agricultural food create farmer produce agriculture sustainable local young rural order farm management access develop
# Topic #1: product market production create produce agricultural make food local farmer farm woman fruit agriculture develop young plant service oil material
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 6}
# precision 48.92086330935252
# Extracting tf features for LDA...
# done in 0.096s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.943s.
#
# Topics in LDA model:
# Topic #0: product make production service market food agricultural create produce farmer sustainable agriculture local young rural order farm management access organization
# Topic #1: product market production create produce agricultural make food farmer local farm agriculture woman fruit develop young service plant management material
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 7}
# precision 46.76258992805755
# Extracting tf features for LDA...
# done in 0.085s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.717s.
#
# Topics in LDA model:
# Topic #0: product make production service market food agricultural create produce farmer sustainable agriculture local young order rural farm management organization access
# Topic #1: product market production create agricultural produce make food farmer local farm agriculture woman develop young fruit service plant management rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 8}
# precision 45.32374100719424
# Extracting tf features for LDA...
# done in 0.062s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.459s.
#
# Topics in LDA model:
# Topic #0: product make production service market food agricultural create produce farmer sustainable local agriculture young order rural farm management organization woman
# Topic #1: product market production create agricultural produce make food farmer local farm agriculture woman develop young service fruit plant management rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 9}
# precision 44.60431654676259
# Extracting tf features for LDA...
# done in 0.068s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.392s.
#
# Topics in LDA model:
# Topic #0: product make production service food market agricultural create produce farmer local sustainable agriculture order young rural farm organization woman management
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop woman young service fruit plant management rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 10}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.068s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.332s.
#
# Topics in LDA model:
# Topic #0: product make production food service market agricultural create produce farmer local sustainable agriculture order young rural farm woman organization management
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop woman young service management fruit plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 11}
# precision 42.87769784172662
# Extracting tf features for LDA...
# done in 0.063s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.308s.
#
# Topics in LDA model:
# Topic #0: product make production food market service agricultural produce create farmer local sustainable agriculture order young rural farm woman organization management
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop young woman service management plant fruit rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 12}
# precision 41.8705035971223
# Extracting tf features for LDA...
# done in 0.069s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.337s.
#
# Topics in LDA model:
# Topic #0: product make production food market service agricultural produce create farmer local sustainable order agriculture farm rural young woman organization management
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop young woman service management plant fruit rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 13}
# precision 41.15107913669065
# Extracting tf features for LDA...
# done in 0.066s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.350s.
#
# Topics in LDA model:
# Topic #0: product make production food market service produce agricultural create farmer local sustainable order agriculture farm rural young woman organization crop
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop young service woman management plant fruit rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 14}
# precision 41.43884892086331
# Extracting tf features for LDA...
# done in 0.073s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.259s.
#
# Topics in LDA model:
# Topic #0: product make production food market service produce agricultural create farmer local sustainable order agriculture farm rural young woman organization crop
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop young service woman management plant fruit rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 15}
# precision 41.294964028776974
# Extracting tf features for LDA...
# done in 0.078s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.197s.
#
# Topics in LDA model:
# Topic #0: product make production food market service produce agricultural create farmer local sustainable order agriculture farm rural young woman organization crop
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop young service woman management plant fruit rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 16}
# precision 41.43884892086331
# Extracting tf features for LDA...
# done in 0.077s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.062s.
#
# Topics in LDA model:
# Topic #0: product make production food market service produce create agricultural farmer local sustainable order farm agriculture rural young woman crop organization
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop young service woman management plant fruit sustainable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 17}
# precision 41.15107913669065
# Extracting tf features for LDA...
# done in 0.061s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.072s.
#
# Topics in LDA model:
# Topic #0: product make production food market service produce create agricultural farmer local sustainable order farm agriculture rural young woman crop organization
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop young service woman management plant fruit sustainable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 18}
# precision 40.719424460431654
# Extracting tf features for LDA...
# done in 0.071s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.821s.
#
# Topics in LDA model:
# Topic #0: product make production food market service produce create agricultural farmer local sustainable farm order agriculture rural young woman crop organization
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop young service woman management plant sustainable fruit
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 19}
# precision 40.719424460431654
# Extracting tf features for LDA...
# done in 0.069s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.012s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local sustainable farm order agriculture rural young woman crop organization
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop young service woman management plant sustainable fruit
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 20}
# precision 40.719424460431654
# Extracting tf features for LDA...
# done in 0.065s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.944s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local sustainable farm order agriculture rural young woman crop organization
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 21}
# precision 39.856115107913666
# Extracting tf features for LDA...
# done in 0.090s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.001s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local sustainable farm order agriculture rural young woman crop organization
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 22}
# precision 39.71223021582734
# Extracting tf features for LDA...
# done in 0.064s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.225s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm sustainable order agriculture rural young woman crop organization
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 23}
# precision 39.71223021582734
# Extracting tf features for LDA...
# done in 0.115s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.946s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm sustainable order agriculture rural young woman crop organization
# Topic #1: product market production create agricultural produce make farmer food local farm agriculture develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 24}
# precision 39.71223021582734
# Extracting tf features for LDA...
# done in 0.095s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.154s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm sustainable order agriculture rural young woman crop organization
# Topic #1: product market production agricultural create produce make farmer food local farm agriculture develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 25}
# precision 39.856115107913666
# Extracting tf features for LDA...
# done in 0.065s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.902s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm sustainable order agriculture rural young woman crop organization
# Topic #1: product market production agricultural create produce make farmer food local farm agriculture develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 26}
# precision 40.28776978417266
# Extracting tf features for LDA...
# done in 0.065s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.950s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm sustainable order agriculture rural young woman crop organization
# Topic #1: product market production agricultural create produce make farmer food local farm agriculture develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 27}
# precision 40.431654676258994
# Extracting tf features for LDA...
# done in 0.064s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.835s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm sustainable order agriculture rural young woman crop organization
# Topic #1: product market production agricultural create produce make farmer food local farm agriculture develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 28}
# precision 40.57553956834533
# Extracting tf features for LDA...
# done in 0.063s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.826s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm sustainable order agriculture rural young woman crop organization
# Topic #1: product market production agricultural create produce make farmer food local farm agriculture develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 29}
# precision 40.431654676258994
# Extracting tf features for LDA...
# done in 0.064s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.855s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm sustainable order agriculture rural young woman crop organization
# Topic #1: product market production agricultural create produce make farmer food local farm agriculture develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 30}
# precision 40.431654676258994
# Extracting tf features for LDA...
# done in 0.068s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.821s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm sustainable order agriculture rural young woman crop organization
# Topic #1: product market production agricultural create produce make farmer food local farm agriculture develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 31}
# precision 40.86330935251799
# Extracting tf features for LDA...
# done in 0.061s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.806s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm sustainable order agriculture rural young woman crop organization
# Topic #1: product market production agricultural create produce make farmer food local agriculture farm develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 32}
# precision 40.86330935251799
# Extracting tf features for LDA...
# done in 0.062s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.833s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm sustainable order agriculture rural young woman crop organization
# Topic #1: product market production agricultural create produce make farmer food local agriculture farm develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 33}
# precision 40.86330935251799
# Extracting tf features for LDA...
# done in 0.064s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.811s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm sustainable order agriculture rural young woman crop organization
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 34}
# precision 41.007194244604314
# Extracting tf features for LDA...
# done in 0.068s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.777s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop organization
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 35}
# precision 41.15107913669065
# Extracting tf features for LDA...
# done in 0.061s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.764s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop organization
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 36}
# precision 41.294964028776974
# Extracting tf features for LDA...
# done in 0.061s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.897s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop organization
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 37}
# precision 41.58273381294964
# Extracting tf features for LDA...
# done in 0.313s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 3.480s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop organization
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 38}
# precision 41.726618705035975
# Extracting tf features for LDA...
# done in 0.115s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.341s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop organization
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 39}
# precision 42.15827338129496
# Extracting tf features for LDA...
# done in 0.119s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.078s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 40}
# precision 42.15827338129496
# Extracting tf features for LDA...
# done in 0.070s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.883s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 41}
# precision 42.15827338129496
# Extracting tf features for LDA...
# done in 0.091s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.970s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 42}
# precision 42.44604316546763
# Extracting tf features for LDA...
# done in 0.116s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.763s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management plant sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 43}
# precision 42.44604316546763
# Extracting tf features for LDA...
# done in 0.087s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.831s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 44}
# precision 42.44604316546763
# Extracting tf features for LDA...
# done in 0.066s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.031s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 45}
# precision 42.589928057553955
# Extracting tf features for LDA...
# done in 0.073s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.753s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 46}
# precision 42.589928057553955
# Extracting tf features for LDA...
# done in 0.074s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.850s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 47}
# precision 42.73381294964029
# Extracting tf features for LDA...
# done in 0.080s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.899s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 48}
# precision 43.02158273381295
# Extracting tf features for LDA...
# done in 0.066s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.943s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 49}
# precision 43.02158273381295
# Extracting tf features for LDA...
# done in 0.094s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.977s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 50}
# precision 43.02158273381295
# Extracting tf features for LDA...
# done in 0.098s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.061s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 51}
# precision 43.30935251798561
# Extracting tf features for LDA...
# done in 0.083s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.110s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 52}
# precision 43.30935251798561
# Extracting tf features for LDA...
# done in 0.114s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 3.317s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 53}
# precision 43.30935251798561
# Extracting tf features for LDA...
# done in 0.129s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.389s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 54}
# precision 43.30935251798561
# Extracting tf features for LDA...
# done in 0.066s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.770s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 55}
# precision 43.30935251798561
# Extracting tf features for LDA...
# done in 0.069s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.757s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 56}
# precision 43.45323741007194
# Extracting tf features for LDA...
# done in 0.071s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.786s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 57}
# precision 43.45323741007194
# Extracting tf features for LDA...
# done in 0.078s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.742s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 58}
# precision 43.597122302158276
# Extracting tf features for LDA...
# done in 0.064s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.733s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 59}
# precision 43.597122302158276
# Extracting tf features for LDA...
# done in 0.072s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.708s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 60}
# precision 43.597122302158276
# Extracting tf features for LDA...
# done in 0.064s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.667s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 61}
# precision 43.597122302158276
# Extracting tf features for LDA...
# done in 0.064s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.703s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 62}
# precision 43.597122302158276
# Extracting tf features for LDA...
# done in 0.064s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.749s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 63}
# precision 43.597122302158276
# Extracting tf features for LDA...
# done in 0.065s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.685s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 64}
# precision 43.7410071942446
# Extracting tf features for LDA...
# done in 0.067s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.682s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 65}
# precision 43.884892086330936
# Extracting tf features for LDA...
# done in 0.072s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.716s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 66}
# precision 43.884892086330936
# Extracting tf features for LDA...
# done in 0.075s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.735s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 67}
# precision 43.884892086330936
# Extracting tf features for LDA...
# done in 0.070s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.701s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 68}
# precision 44.02877697841727
# Extracting tf features for LDA...
# done in 0.068s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.666s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 69}
# precision 44.172661870503596
# Extracting tf features for LDA...
# done in 0.064s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.705s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 70}
# precision 44.172661870503596
# Extracting tf features for LDA...
# done in 0.063s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.655s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 71}
# precision 44.172661870503596
# Extracting tf features for LDA...
# done in 0.066s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.298s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 72}
# precision 44.172661870503596
# Extracting tf features for LDA...
# done in 0.068s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.704s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 73}
# precision 44.172661870503596
# Extracting tf features for LDA...
# done in 0.070s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.752s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 74}
# precision 44.172661870503596
# Extracting tf features for LDA...
# done in 0.064s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.657s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 75}
# precision 44.172661870503596
# Extracting tf features for LDA...
# done in 0.064s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.687s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 76}
# precision 44.172661870503596
# Extracting tf features for LDA...
# done in 0.067s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.636s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 77}
# precision 44.172661870503596
# Extracting tf features for LDA...
# done in 0.077s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.555s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 78}
# precision 44.02877697841727
# Extracting tf features for LDA...
# done in 0.083s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.683s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 79}
# precision 44.172661870503596
# Extracting tf features for LDA...
# done in 0.068s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.658s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 80}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.065s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.705s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 81}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.068s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.701s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 82}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.067s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.775s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 83}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.079s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.720s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 84}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.077s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.676s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 85}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.069s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.645s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 86}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.067s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.697s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 87}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.066s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.673s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 88}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.065s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.669s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 89}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.094s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.746s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 90}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.069s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.699s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 91}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.084s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.711s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 92}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.075s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.698s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 93}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.067s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.714s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 94}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.065s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.645s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 95}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.065s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.660s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 96}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.066s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.659s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 97}
# precision 44.31654676258992
# Extracting tf features for LDA...
# done in 0.068s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.690s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 98}
# precision 44.460431654676256
# Extracting tf features for LDA...
# done in 0.069s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.914s.
#
# Topics in LDA model:
# Topic #0: product production make food market service produce create agricultural farmer local farm order sustainable agriculture rural young woman crop management
# Topic #1: product market production agricultural create make produce farmer food local agriculture farm develop young service woman management sustainable plant rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 99}
# precision 44.460431654676256

# %%
model_parameters = {'n_components' : 2, 'n_top_words' : 20, 'n_features' : 20000, 'doc_topic_prior':None}
run_model_lda(model_parameters,text_corpus)
# Out:
# Extracting tf features for LDA...
# done in 0.098s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.300s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable rural develop management order
# Topic #1: régional ponds recreation entrepreneures agricoles conseil zou collines product tel breed email une pond president promoter council farmer en tilapia
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': None}
# precision 98.41726618705036
# {'n_components': 2,
#  'n_top_words': 20,
#  'n_features': 20000,
#  'doc_topic_prior': None,
#  'precision': 98.41726618705036,
#  'vocabulaire': ['ab',
#   'abandon',
#   'abc',
#   'abeokuta',
#   'ability',
#   'abomeycalavi',
#   'abound',
#   'abroad',
#   'absence',
#   'absorb',
#   'abuja',
#   'abundance',
#   'abundant',
#   'abuse',
#   'ac',
#   'academic',
#   'academy',
#   'accelerate',
#   'acceleration',
#   'accelerator',
#   'accept',
#   'access',
#   'accessibility',
#   'accessible',
#   'accessory',
#   'accident',
#   'accompanies',
#   'accompaniment',
#   'accompany',
#   'accompanying',
#   'accordance',
#   'account',
#   'accountant',
#   'accounting',
#   'accurate',
#   'achievable',
#   'achievement',
#   'acid',
#   'acidic',
#   'acidity',
#   'acknowledge',
#   'acquire',
#   'acquisition',
#   'acre',
#   'acronym',
#   'act',
#   'active',
#   'actively',
#   'actor',
#   'actual',
#   'actually',
#   'ad',
#   'adapt',
#   'adaptable',
#   'adaptation',
#   'adapted',
#   'adaptive',
#   'adapts',
#   'additional',
#   'additionally',
#   'additive',
#   'additives',
#   'address',
#   'adequate',
#   'adhere',
#   'adjustment',
#   'administer',
#   'administration',
#   'administrative',
#   'administrator',
#   'adolescent',
#   'adopt',
#   'adoption',
#   'adult',
#   'advance',
#   'advanced',
#   'advancement',
#   'advantage',
#   'advantageous',
#   'adventure',
#   'advertise',
#   'advertisement',
#   'advertiser',
#   'advertising',
#   'advice',
#   'advise',
#   'adviser',
#   'advisor',
#   'advisory',
#   'advocacy',
#   'advocate',
#   'aerial',
#   'aesthetic',
#   'affair',
#   'affect',
#   'affected',
#   'afford',
#   'affordability',
#   'affordable',
#   'afp',
#   'afribusiness',
#   'afric',
#   'africain',
#   'africas',
#   'aftersales',
#   'age',
#   'agence',
#   'agency',
#   'agenda',
#   'agent',
#   'aggregate',
#   'aggregated',
#   'aggregation',
#   'aggregator',
#   'ago',
#   'agreement',
#   'agri',
#   'agribusiness',
#   'agribusinesses',
#   'agric',
#   'agricole',
#   'agricoles',
#   'agricultural',
#   'agriculture',
#   'agricultureour',
#   'agrifood',
#   'agripreneurs',
#   'agriproduce',
#   'agritech',
#   'agritenants',
#   'agritourism',
#   'agroalimentaire',
#   'agrobusiness',
#   'agrochemicals',
#   'agroclimatic',
#   'agroecological',
#   'agroecology',
#   'agroenterprise',
#   'agrofood',
#   'agroforestry',
#   'agroindustrial',
#   'agroindustry',
#   'agronomic',
#   'agronomist',
#   'agronomists',
#   'agronomy',
#   'agropastoral',
#   'agroprocessing',
#   'agtech',
#   'ahead',
#   'ai',
#   'aid',
#   'aims',
#   'air',
#   'airport',
#   'akwa',
#   'al',
#   'alarm',
#   'alcohol',
#   'alcoholic',
#   'alert',
#   'algae',
#   'algorithm',
#   'algorithms',
#   'alicament',
#   'align',
#   'allada',
#   'alleviate',
#   'alleviation',
#   'alliance',
#   'allocation',
#   'ally',
#   'alongside',
#   'alteration',
#   'alternate',
#   'alumnus',
#   'amani',
#   'amaranth',
#   'amateur',
#   'amazing',
#   'amazon',
#   'ambition',
#   'ambitious',
#   'amendment',
#   'america',
#   'american',
#   'amino',
#   'analyse',
#   'analysis',
#   'analyst',
#   'analytical',
#   'analytics',
#   'analyze',
#   'ancestral',
#   'andor',
#   'android',
#   'anemia',
#   'angola',
#   'angolan',
#   'animal',
#   'animals',
#   'animate',
#   'animation',
#   'announce',
#   'announcement',
#   'annual',
#   'annum',
#   'answer',
#   'antananarivo',
#   'antibacterial',
#   'antibiotic',
#   'anticipate',
#   'anticipation',
#   'antifungal',
#   'antiinflammatory',
#   'antioxidant',
#   'antiseptic',
#   'antispasmodic',
#   'antiviral',
#   'anymore',
#   'apart',
#   'apartment',
#   'apolitical',
#   'app',
#   'appeal',
#   'appear',
#   'appearance',
#   'appellation',
#   'appetite',
#   'appetizer',
#   'apple',
#   'appliance',
#   'applicable',
#   'application',
#   'apply',
#   'appreciate',
#   'appreciated',
#   'appreciation',
#   'approach',
#   'approached',
#   'appropriate',
#   'approval',
#   'approve',
#   'approximately',
#   'apps',
#   'apricot',
#   'april',
#   'aqua',
#   'aquaculture',
#   'aquagritech',
#   'aquaponic',
#   'aquaponics',
#   'aquatic',
#   'arabic',
#   'arable',
#   'arboriculture',
#   'architectural',
#   'architecture',
#   'archive',
#   'areasthe',
#   'areaswe',
#   'argan',
#   'arise',
#   'arm',
#   'aromatic',
#   'arrange',
#   'array',
#   'arrive',
#   'arrondissement',
#   'art',
#   'article',
#   'artificial',
#   'artisan',
#   'artisanal',
#   'artisans',
#   'artist',
#   'artistic',
#   'asia',
#   'aside',
#   'ask',
#   'aspect',
#   'aspects',
#   'asphalt',
#   'assemble',
#   'assembly',
#   'assert',
#   'assessment',
#   'asset',
#   'assimilate',
#   'assist',
#   'assistance',
#   'assistant',
#   'associate',
#   'association',
#   'associations',
#   'assurance',
#   'assure',
#   'attach',
#   'attack',
#   'attain',
#   'attempt',
#   'attend',
#   'attention',
#   'attieke',
#   'attitude',
#   'attiéké',
#   'attract',
#   'attraction',
#   'attractive',
#   'attractiveness',
#   'au',
#   'audience',
#   'audiences',
#   'audio',
#   'audiovisual',
#   'audit',
#   'auditor',
#   'august',
#   'authentic',
#   'authenticity',
#   'author',
#   'authority',
#   'authorize',
#   'automate',
#   'automatic',
#   'automatically',
#   'automation',
#   'autonomous',
#   'autonomy',
#   'aux',
#   'avail',
#   'availability',
#   'avec',
#   'avenue',
#   'aviation',
#   'avocado',
#   'avocados',
#   'awaken',
#   'award',
#   'awardwinning',
#   'aware',
#   'awareness',
#   'away',
#   'ax',
#   'axis',
#   'ba',
#   'baby',
#   'background',
#   'backyard',
#   'bacteria',
#   'bacterial',
#   'bad',
#   'badly',
#   'bag',
#   'bags',
#   'bake',
#   'baker',
#   'bakery',
#   'baking',
#   'balance',
#   'balanites',
#   'balcony',
#   'bale',
#   'ball',
#   'bamako',
#   'bamboo',
#   'banana',
#   'bananas',
#   'band',
#   'bandwidth',
#   'bangui',
#   'bank',
#   'banking',
#   'banner',
#   'baobab',
#   'bar',
#   'barnes',
#   'barrel',
#   'barrier',
#   'barry',
#   'basic',
#   'basically',
#   'basil',
#   'basin',
#   'basis',
#   'basket',
#   'basketballbasketball',
#   'baskets',
#   'batch',
#   'bath',
#   'battery',
#   'bb',
#   'bbbee',
#   'bbc',
#   'bc',
#   'bean',
#   'bear',
#   'bearer',
#   'beautification',
#   'beautiful',
#   'beauty',
#   'bed',
#   'bee',
#   'beef',
#   'beekeeper',
#   'beekeeping',
#   'beer',
#   'beet',
#   'begin',
#   'beginner',
#   'beginning',
#   'behalf',
#   'behavior',
#   'behaviour',
#   'behavioural',
#   'behaviours',
#   'belief',
#   'believe',
#   'belong',
#   'belongs',
#   'beloved',
#   'beneficial',
#   'beneficiary',
#   'benefit',
#   'beninese',
#   'berlin',
#   'berry',
#   'bet',
#   'beta',
#   'beverage',
#   'bicycle',
#   'bilanga',
#   'billboard',
#   'biltong',
#   'bin',
#   'bingerville',
#   'bio',
#   'biochar',
#   'biodegradable',
#   'biodiesel',
#   'biodigesters',
#   'biodiversity',
#   'biofertilizer',
#   'biofertilizers',
#   'biofood',
#   'biofuel',
#   'biogas',
#   'biointensive',
#   'biological',
#   'biology',
#   'biomass',
#   'biosecurity',
#   'biotechnology',
#   'biowaste',
#   'bird',
#   'birth',
#   'birthday',
#   'biscuit',
#   'biscuits',
#   'bissap',
#   'bite',
#   'bitter',
#   'bleach',
#   'blend',
#   'blending',
#   'block',
#   'blockchain',
#   'blog',
#   'blood',
#   'blue',
#   'bn',
#   'board',
#   'boast',
#   'bobo',
#   'body',
#   'bohicon',
#   'boil',
#   'boldly',
#   'bone',
#   'book',
#   'bookstore',
#   'boom',
#   'boost',
#   'bop',
#   'border',
#   'borehole',
#   'boreholes',
#   'born',
#   'botswana',
#   'bottle',
#   'bought',
#   'bouillon',
#   'bouquet',
#   'bovine',
#   'box',
#   'boys',
#   'bp',
#   'brain',
#   'brake',
#   'bran',
#   'branch',
#   'brand',
#   'branding',
#   'brandy',
#   'brazzaville',
#   'bread',
#   'break',
#   'breakdown',
#   'breakfast',
#   'breast',
#   'breastfeed',
#   'breed',
#   'breeder',
#   'breeding',
#   'brew',
#   'brewery',
#   'brick',
#   'bridge',
#   'bridging',
#   'brief',
#   'briefing',
#   'bright',
#   'bring',
#   'bringing',
#   'brings',
#   'briquette',
#   'broad',
#   'broadcast',
#   'broiler',
#   'broken',
#   'broker',
#   'brood',
#   'broth',
#   'brought',
#   'brown',
#   'bsc',
#   'bsf',
#   'bsquare',
#   'bubanza',
#   'bucket',
#   'bud',
#   'budget',
#   'budgeting',
#   'bug',
#   'build',
#   'building',
#   'buildup',
#   'built',
#   'bujumbura',
#   'bukavu',
#   'bulawayo',
#   'bulb',
#   'bulk',
#   'bulky',
#   'bull',
#   'burden',
#   'bureau',
#   'burger',
#   'burkinabe',
#   'burkinabè',
#   'burn',
#   'burundian',
#   'bus',
#   'busy',
#   'butcher',
#   'butchery',
#   'butter',
#   'button',
#   'buy',
#   'buying',
#   'byproduct',
#   'byproducts',
#   'bénin',
#   'cabbage',
#   'cage',
#   'cake',
#   'calcium',
#   'calculate',
#   'calculation',
#   'calendar',
#   'california',
#   'calorie',
#   'camera',
#   'cameroonian',
#   'camp',
#   'campaign',
#   'canaan',
#   'canada',
#   'cancer',
#   'candidate',
#   'candy',
#   'cane',
#   'cap',
#   'capability',
#   'capable',
#   'capacitate',
#   'cape',
#   'capital',
#   'capitalize',
#   'capsule',
#   'capture',
#   'caramel',
#   'carbohydrate',
#   'carbohydrates',
#   'carbon',
#   'carcinogenic',
#   'card',
#   'cardiovascular',
#   'care',
#   'career',
#   'carefully',
#   'carp',
#   'carpentry',
#   'carrefour',
#   'carried',
#   'carrot',
#   'carrots',
#   'carry',
#   'cartography',
#   'casamance',
#   'case',
#   'cash',
#   'cashew',
#   'cashflow',
#   'cashless',
#   'casino',
#   'cassava',
#   'casual',
#   'cat',
#   'catalogue',
#   'catalyst',
#   'cater',
#   'caterer',
#   'catering',
#   'catfish',
#   'catholic',
#   'cattle',
#   'cauldron',
#   'caused',
#   'causing',
#   'cayenne',
#   'cbd',
#   'celery',
#   'cell',
#   'cellular',
#   'celsius',
#   'cement',
#   'centric',
#   'century',
#   'ceo',
#   'cereal',
#   'certain',
#   'certainly',
#   'certificate',
#   'certification',
#   'certified',
#   'certify',
#   'cf',
#   'cfo',
#   'chadian',
#   'chain',
#   'chair',
#   'chamber',
#   'champion',
#   'chance',
#   'channel',
#   'chapter',
#   'character',
#   'characteristic',
#   'characterize',
#   'charcoal',
#   'charge',
#   'charity',
#   'cheap',
#   'cheaper',
#   'check',
#   'cheese',
#   'chef',
#   'chemical',
#   'cherry',
#   'chick',
#   'chicken',
#   'chickens',
#   'chief',
#   'child',
#   'childhood',
#   'childrens',
#   'chili',
#   'chilli',
#   'china',
#   'chip',
#   'chirapatre',
#   'chocolate',
#   'chocolates',
#   'choice',
#   'cholesterol',
#   'cholesterolfree',
#   'choose',
#   'chosen',
#   'christian',
#   'chronic',
#   'church',
#   'chutney',
#   'ci',
#   'cinema',
#   'cinnamon',
#   'cip',
#   'circuit',
#   'circular',
#   'circulation',
#   'citizen',
#   'citizens',
#   'citrus',
#   'city',
#   'civagrihack',
#   'civic',
#   'civil',
#   'claim',
#   'clarias',
#   'class',
#   'classic',
#   'classify',
#   'clay',
#   'clean',
#   'cleaner',
#   'cleaning',
#   'clear',
#   'clearly',
#   'click',
#   'climate',
#   'climatesmart',
#   'climatic',
#   'climb',
#   'clinic',
#   'clinicagro',
#   'clip',
#   'close',
#   'closely',
#   'closer',
#   'clothes',
#   'cloud',
#   'clove',
#   'club',
#   'cluster',
#   'cm',
#   'coach',
#   'coaching',
#   'coal',
#   'coastal',
#   'coat',
#   'cock',
#   'cocktail',
#   'cocoa',
#   'cocody',
#   'coconut',
#   'coconutbased',
#   'cod',
#   'code',
#   'coffee',
#   'cofounded',
#   'cofounder',
#   'coherent',
#   'collaborate',
#   'collaborates',
#   'collaboration',
#   'collaborative',
#   'collaborator',
#   'collapse',
#   'collar',
#   'collect',
#   'collection',
#   'collective',
#   'collectively',
#   'collector',
#   'college',
#   'collines',
#   'colony',
#   'color',
#   'colour',
#   'combat',
#   'combination',
#   'combine',
#   'combining',
#   'combustion',
#   'comedian',
#   'comfort',
#   'comic',
#   'command',
#   'commence',
#   'commencement',
#   'commerce',
#   'commercial',
#   'commercialization',
#   'commercialize',
#   'commercially',
#   'commission',
#   'commit',
#   'commitment',
#   'committed',
#   'committee',
#   'commodities',
#   'commodity',
#   'common',
#   'commonly',
#   'communal',
#   'communicate',
#   'communication',
#   'communities',
#   'community',
#   'communitybased',
#   'comorian',
#   'comoros',
#   'companys',
#   'companythe',
#   'comparable',
#   'comparative',
#   'compare',
#   'comparison',
#   'compensate',
#   'compete',
#   'competence',
#   'competent',
#   'competes',
#   'competition',
#   'competitive',
#   'competitor',
#   'complement',
#   'complementary',
#   'complete',
#   'completely',
#   'complex',
#   'compliance',
#   'complicate',
#   'component',
#   'compose',
#   'composed',
#   'composite',
#   'composition',
#   'compost',
#   'compote',
#   'compound',
#   'comprehensive',
#   'comprise',
#   'comprises',
#   'compute',
#   'computer',
#   'computerize',
#   'concentrate',
#   'concentrated',
#   'concentration',
#   'concept',
#   'conception',
#   'conceptual',
#   'concerned',
#   'concession',
#   'conclude',
#   'concrete',
#   'concretely',
#   'condiment',
#   'condition',
#   'conditioner',
#   'conducive',
#   'conduct',
#   'conducted',
#   'confectionery',
#   'conference',
#   'confidence',
#   'confident',
#   'configuration',
#   'confine',
#   'conflict',
#   'confront',
#   'connect',
#   'connecting',
#   'connection',
#   'connectivity',
#   'connects',
#   'connexion',
#   'conscious',
#   'conseil',
#   'conseils',
#   'consequence',
#   'consequently',
#   'conservation',
#   'conserve',
#   'consider',
#   'considerable',
#   'considerably',
#   'consideration',
#   'consist',
#   'consistent',
#   'consists',
#   'consolidate',
#   'consortium',
#   'constant',
#   'constantin',
#   'constantly',
#   'constipation',
#   'constitute',
#   'constitutes',
#   'constraint',
#   'construct',
#   'construction',
#   'consult',
#   'consultancy',
#   'consultant',
#   'consultation',
#   'consulting',
#   'consumable',
#   'consumables',
#   'consumed',
#   'consumption',
#   'contact',
#   'contain',
#   'container',
#   'containing',
#   'contains',
#   'contaminate',
#   'contamination',
#   'contemporary',
#   'content',
#   'context',
#   'continually',
#   'continue',
#   'continuous',
#   'continuously',
#   'contract',
#   'contractor',
#   'contrast',
#   'contributes',
#   'contribution',
#   'contributor',
#   'control',
#   'convenience',
#   'convenient',
#   'conventional',
#   'conversion',
#   'convert',
#   'conviction',
#   'convince',
#   'cook',
#   'cooker',
#   'cooking',
#   'cooky',
#   'cooler',
#   'cooperate',
#   'cooperation',
#   'cooperative',
#   'cooperatives',
#   'cooperator',
#   'coordinate',
#   'coordination',
#   'coordinator',
#   'cope',
#   'copper',
#   'copy',
#   'corchorus',
#   'core',
#   'corn',
#   'corner',
#   'corossol',
#   'corp',
#   'corporate',
#   'corporates',
#   'corporation',
#   'correct',
#   'correspond',
#   'correspondent',
#   'cosmetic',
#   'costeffective',
#   'costefficient',
#   'costly',
#   'cote',
#   'cotonou',
#   'cotton',
#   'cough',
#   'coulibaly',
#   'council',
#   'counsel',
#   'count',
#   'counter',
#   'countrys',
#   'county',
#   'couple',
#   'course',
#   'couscous',
#   'cover',
#   'coverage',
#   'covered',
#   'cow',
#   'craft',
#   'craftsman',
#   'craftsmanship',
#   'crate',
#   'cream',
#   'create',
#   'creates',
#   'creation',
#   'creative',
#   'creatively',
#   ...]}

# %%
list_model_parameters_nfeatures = [{'n_components' : 2, 'n_top_words' : 20, 'n_features' : n_features, 'doc_topic_prior':None} for n_features in range(500,5000,100)]

list_run = []
for model_parameters in list_model_parameters_nfeatures:
    list_run.append(run_model_lda(model_parameters,text_corpus))
results_n_features = pandas.DataFrame(list_run).sort_values('precision', ascending = False)
# Out:
# Extracting tf features for LDA...
# done in 0.087s.
#
# Fitting LDA models with tf features, n_features=500...
# done in 2.504s.
#
# Topics in LDA model:
# Topic #0: service agricultural make market create farmer management product agriculture platform young develop community local field access technology rural production farm
# Topic #1: product production produce food market make create agricultural woman local farm fruit farmer organic vegetable natural plant agriculture oil sustainable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 500, 'doc_topic_prior': None}
# precision 39.13669064748201
# Extracting tf features for LDA...
# done in 0.078s.
#
# Fitting LDA models with tf features, n_features=600...
# done in 2.324s.
#
# Topics in LDA model:
# Topic #0: service farmer platform market agricultural make create community access management rural technology social develop product agriculture information digital young farm
# Topic #1: product production market produce food make create agricultural local woman farm farmer organic agriculture fruit young vegetable plant natural sustainable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 600, 'doc_topic_prior': None}
# precision 30.503597122302157
# Extracting tf features for LDA...
# done in 0.059s.
#
# Fitting LDA models with tf features, n_features=700...
# done in 2.331s.
#
# Topics in LDA model:
# Topic #0: service platform market make young management information digital farmer create agricultural team social access local group mobile develop communication community
# Topic #1: product production market produce food make agricultural create farmer farm local agriculture woman sustainable organic service fruit young rural plant
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 700, 'doc_topic_prior': None}
# precision 20.863309352517987
# Extracting tf features for LDA...
# done in 0.061s.
#
# Fitting LDA models with tf features, n_features=800...
# done in 1.588s.
#
# Topics in LDA model:
# Topic #0: powder make product produce food transformation tea local farmer production rural moringa woman specialized create team waste flour dedicate distribute
# Topic #1: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable develop rural management order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 800, 'doc_topic_prior': None}
# precision 1.5827338129496402
# Extracting tf features for LDA...
# done in 0.065s.
#
# Fitting LDA models with tf features, n_features=900...
# done in 2.281s.
#
# Topics in LDA model:
# Topic #0: product food production oil produce fruit market woman make natural vegetable raw local organic agricultural health young plant palm crop
# Topic #1: product market make create agricultural production service farmer produce farm agriculture local food management sustainable young develop rural social order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 900, 'doc_topic_prior': None}
# precision 26.47482014388489
# Extracting tf features for LDA...
# done in 0.062s.
#
# Fitting LDA models with tf features, n_features=1000...
# done in 2.786s.
#
# Topics in LDA model:
# Topic #0: service market agricultural farmer make create platform product young local management organization information group develop social digital community train farm
# Topic #1: product production food produce market make create agricultural farmer farm agriculture local organic sustainable woman fruit vegetable rural plant natural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1000, 'doc_topic_prior': None}
# precision 29.496402877697843
# Extracting tf features for LDA...
# done in 0.062s.
#
# Fitting LDA models with tf features, n_features=1100...
# done in 2.832s.
#
# Topics in LDA model:
# Topic #0: product food production produce market make farmer agricultural local farm fruit create woman oil agriculture rural vegetable crop natural fresh
# Topic #1: create market service agricultural make product management young production sustainable farmer agriculture local farm develop field social group platform order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1100, 'doc_topic_prior': None}
# precision 52.0863309352518
# Extracting tf features for LDA...
# done in 0.066s.
#
# Fitting LDA models with tf features, n_features=1200...
# done in 1.844s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food service farmer local farm agriculture young woman sustainable rural develop management order
# Topic #1: fish farmer tilapia pond feed breed presentation product council promoter creation president partner address turmeric organic spice food production agricultural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1200, 'doc_topic_prior': None}
# precision 97.6978417266187
# Extracting tf features for LDA...
# done in 0.095s.
#
# Fitting LDA models with tf features, n_features=1300...
# done in 2.447s.
#
# Topics in LDA model:
# Topic #0: product production market produce food make create agricultural local farmer farm agriculture woman organic fruit young sustainable vegetable plant natural
# Topic #1: service platform create agricultural make access management develop market community technology farmer young social information digital product rural team agriculture
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1300, 'doc_topic_prior': None}
# precision 73.66906474820144
# Extracting tf features for LDA...
# done in 0.063s.
#
# Fitting LDA models with tf features, n_features=1400...
# done in 1.613s.
#
# Topics in LDA model:
# Topic #0: product market production make agricultural create produce food service farmer local farm agriculture young sustainable rural woman develop management order
# Topic #1: president association presentation create unite market foundation organization group union farmer des woman information list hold peasant officer sit partner
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1400, 'doc_topic_prior': None}
# precision 98.41726618705036
# Extracting tf features for LDA...
# done in 0.064s.
#
# Fitting LDA models with tf features, n_features=1500...
# done in 2.268s.
#
# Topics in LDA model:
# Topic #0: product production market food produce make agricultural farmer create farm local agriculture woman organic fruit plant vegetable rural sustainable crop
# Topic #1: service create young management market information platform make social team develop group organization digital community sustainable field agricultural technology local
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1500, 'doc_topic_prior': None}
# precision 78.84892086330936
# Extracting tf features for LDA...
# done in 0.059s.
#
# Fitting LDA models with tf features, n_features=1600...
# done in 2.771s.
#
# Topics in LDA model:
# Topic #0: service market agricultural platform make farmer create product management information local social develop digital access community agriculture field order young
# Topic #1: product production produce market food make create agricultural farmer local woman farm agriculture sustainable young organic fruit vegetable rural service
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1600, 'doc_topic_prior': None}
# precision 27.769784172661872
# Extracting tf features for LDA...
# done in 0.067s.
#
# Fitting LDA models with tf features, n_features=1700...
# done in 3.379s.
#
# Topics in LDA model:
# Topic #0: product market production food make produce agricultural local woman farm farmer organic service oil fruit natural health vegetable young create
# Topic #1: create product make agricultural production service farmer market rural produce agriculture young food sustainable technology community management farm local develop
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1700, 'doc_topic_prior': None}
# precision 46.043165467625904
# Extracting tf features for LDA...
# done in 0.065s.
#
# Fitting LDA models with tf features, n_features=1800...
# done in 1.528s.
#
# Topics in LDA model:
# Topic #0: product market production entertainment make broiler meat farm advertising bird service produce river try egg founder surface poultry agricultural farming
# Topic #1: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable rural develop management order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1800, 'doc_topic_prior': None}
# precision 1.4388489208633095
# Extracting tf features for LDA...
# done in 0.067s.
#
# Fitting LDA models with tf features, n_features=1900...
# done in 2.550s.
#
# Topics in LDA model:
# Topic #0: service create agricultural market management young make platform field product develop community social farmer sustainable information group organization local access
# Topic #1: product production produce market food make agricultural create farm farmer local agriculture fruit organic woman vegetable plant natural rural oil
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1900, 'doc_topic_prior': None}
# precision 31.510791366906478
# Extracting tf features for LDA...
# done in 0.069s.
#
# Fitting LDA models with tf features, n_features=2000...
# done in 2.062s.
#
# Topics in LDA model:
# Topic #0: product production fruit food oil juice natural produce sugar transformation ginger local nut market make pineapple palm rich fresh woman
# Topic #1: product market make production create agricultural produce farmer service food farm agriculture local young sustainable rural develop management woman order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2000, 'doc_topic_prior': None}
# precision 13.525179856115107
# Extracting tf features for LDA...
# done in 0.069s.
#
# Fitting LDA models with tf features, n_features=2100...
# done in 1.409s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable rural develop management order
# Topic #1: product une entertainment make market service production en communication advertising zou agricultural video farming tailor thrive farmer create local pour
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2100, 'doc_topic_prior': None}
# precision 98.70503597122303
# Extracting tf features for LDA...
# done in 0.070s.
#
# Fitting LDA models with tf features, n_features=2200...
# done in 1.627s.
#
# Topics in LDA model:
# Topic #0: product bissap market local make ginger juice food natural production ceo herbal une lemon moringa agricultural farm lemongrass rural pour
# Topic #1: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable develop rural management order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2200, 'doc_topic_prior': None}
# precision 2.446043165467626
# Extracting tf features for LDA...
# done in 0.074s.
#
# Fitting LDA models with tf features, n_features=2300...
# done in 1.814s.
#
# Topics in LDA model:
# Topic #0: product market breed make ginger egg production zou local en hen chicken produce juice agricultural presentation lay natural february lemon
# Topic #1: product market production make create agricultural food produce farmer service local farm agriculture young sustainable woman rural develop management order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2300, 'doc_topic_prior': None}
# precision 4.60431654676259
# Extracting tf features for LDA...
# done in 0.074s.
#
# Fitting LDA models with tf features, n_features=2400...
# done in 2.075s.
#
# Topics in LDA model:
# Topic #0: product market production make agricultural create produce food farmer service local farm agriculture young sustainable rural develop management woman order
# Topic #1: product production fruit food market juice oil natural make produce transformation ginger sugar palm nut soap woman create local milk
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2400, 'doc_topic_prior': None}
# precision 87.33812949640289
# Extracting tf features for LDA...
# done in 0.075s.
#
# Fitting LDA models with tf features, n_features=2500...
# done in 2.023s.
#
# Topics in LDA model:
# Topic #0: product market production local en make fruit transformation farm fresh food agricultural february group hen chicken produce ginger juice garden
# Topic #1: product market production make create agricultural produce food farmer service local agriculture farm young woman sustainable develop rural management order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2500, 'doc_topic_prior': None}
# precision 8.057553956834532
# Extracting tf features for LDA...
# done in 0.069s.
#
# Fitting LDA models with tf features, n_features=2600...
# done in 1.547s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable rural develop management order
# Topic #1: product market make ginger produce local bread une cake pour farmer lemon cocktail agricultural production en juice entertainment live service
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2600, 'doc_topic_prior': None}
# precision 97.98561151079137
# Extracting tf features for LDA...
# done in 0.070s.
#
# Fitting LDA models with tf features, n_features=2700...
# done in 3.023s.
#
# Topics in LDA model:
# Topic #0: service market agricultural product create make farmer management agriculture local farm young platform community develop production social rural technology access
# Topic #1: product production produce food market make create agricultural fruit woman organic farmer local vegetable farm natural oil agriculture plant sustainable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2700, 'doc_topic_prior': None}
# precision 43.16546762589928
# Extracting tf features for LDA...
# done in 0.064s.
#
# Fitting LDA models with tf features, n_features=2800...
# done in 1.876s.
#
# Topics in LDA model:
# Topic #0: product en breed juice zou production market presentation fruit february make hen creation sugar pineapple farmer les local transformation egg
# Topic #1: product market production make create agricultural produce food farmer service local agriculture farm young woman sustainable rural develop management order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2800, 'doc_topic_prior': None}
# precision 4.028776978417266
# Extracting tf features for LDA...
# done in 0.068s.
#
# Fitting LDA models with tf features, n_features=2900...
# done in 2.448s.
#
# Topics in LDA model:
# Topic #0: product market educational platform service travel art create une make entertainment local cow pour brand young book author publish application
# Topic #1: product market production make agricultural create produce food farmer service local farm agriculture young woman sustainable rural develop management order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2900, 'doc_topic_prior': None}
# precision 1.1510791366906474
# Extracting tf features for LDA...
# done in 0.071s.
#
# Fitting LDA models with tf features, n_features=3000...
# done in 1.400s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable rural develop management order
# Topic #1: zou president tel recreation ponds conseil agricoles collines farmer promoter email breed creation council presentation pond tilapia fish partner address
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3000, 'doc_topic_prior': None}
# precision 98.84892086330936
# Extracting tf features for LDA...
# done in 0.097s.
#
# Fitting LDA models with tf features, n_features=3100...
# done in 2.222s.
#
# Topics in LDA model:
# Topic #0: product farmer food make president production natural milk breed woman health agricultural juice energy weight vegetable presentation market property produce
# Topic #1: product market production make create agricultural produce food service farmer local agriculture farm young sustainable develop woman rural management order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3100, 'doc_topic_prior': None}
# precision 3.597122302158273
# Extracting tf features for LDA...
# done in 0.070s.
#
# Fitting LDA models with tf features, n_features=3200...
# done in 1.648s.
#
# Topics in LDA model:
# Topic #0: farmer fish tilapia feed breed pond zou recreation conseil ponds president presentation agricoles collines promoter tel council creation email partner
# Topic #1: product market production make create agricultural produce food service farmer local farm agriculture young woman sustainable rural develop management order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3200, 'doc_topic_prior': None}
# precision 1.870503597122302
# Extracting tf features for LDA...
# done in 0.067s.
#
# Fitting LDA models with tf features, n_features=3300...
# done in 1.410s.
#
# Topics in LDA model:
# Topic #0: recreation tel ponds zou farmer conseil president agricoles promoter collines breed fish email pond council presentation tilapia feed creation address
# Topic #1: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable rural develop management order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3300, 'doc_topic_prior': None}
# precision 1.1510791366906474
# Extracting tf features for LDA...
# done in 0.067s.
#
# Fitting LDA models with tf features, n_features=3400...
# done in 1.747s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food service farmer local agriculture farm young woman sustainable rural develop management order
# Topic #1: farmer fish feed breed product tilapia farm make pond recreation address ponds production creation zou tel promoter partner president presentation
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3400, 'doc_topic_prior': None}
# precision 97.2661870503597
# Extracting tf features for LDA...
# done in 0.115s.
#
# Fitting LDA models with tf features, n_features=3500...
# done in 2.698s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food farmer service local farm agriculture young sustainable woman rural develop management order
# Topic #1: product juice production fruit sugar en pineapple oil food ginger transformation les make creation fresh farmer nut drop crop recreation
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3500, 'doc_topic_prior': None}
# precision 95.97122302158273
# Extracting tf features for LDA...
# done in 0.063s.
#
# Fitting LDA models with tf features, n_features=3600...
# done in 2.707s.
#
# Topics in LDA model:
# Topic #0: service create management young sustainable community make social organization product develop market rural information agricultural field group platform local digital
# Topic #1: product market production food produce make agricultural farmer farm create local agriculture woman fruit organic plant service crop vegetable young
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3600, 'doc_topic_prior': None}
# precision 26.618705035971225
# Extracting tf features for LDA...
# done in 0.066s.
#
# Fitting LDA models with tf features, n_features=3700...
# done in 1.628s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food farmer service local farm agriculture young sustainable rural develop woman management order
# Topic #1: product juice sugar ginger food production natural transformation fruit nut milk pineapple oil produce spice association dietary make diabetes digestion
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3700, 'doc_topic_prior': None}
# precision 94.67625899280576
# Extracting tf features for LDA...
# done in 0.073s.
#
# Fitting LDA models with tf features, n_features=3800...
# done in 1.310s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable rural develop management order
# Topic #1: recreation ponds zou régional conseil agricoles collines tel product email president council promoter une en pour presentation breed pond tilapia
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3800, 'doc_topic_prior': None}
# precision 97.84172661870504
# Extracting tf features for LDA...
# done in 0.072s.
#
# Fitting LDA models with tf features, n_features=3900...
# done in 1.876s.
#
# Topics in LDA model:
# Topic #0: recreation presentation régional ponds entrepreneures zou tel conseil agricoles president collines promoter breed product email farmer creation feed council pond
# Topic #1: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable develop rural management order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3900, 'doc_topic_prior': None}
# precision 1.7266187050359711
# Extracting tf features for LDA...
# done in 0.092s.
#
# Fitting LDA models with tf features, n_features=4000...
# done in 2.044s.
#
# Topics in LDA model:
# Topic #0: product market production make agricultural create produce food farmer service local farm agriculture young woman sustainable rural develop management order
# Topic #1: product farmer creation promoter feed partner recreation ponds email presentation tel breed fish president tilapia zou address entrepreneures régional conseil
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4000, 'doc_topic_prior': None}
# precision 97.41007194244604
# Extracting tf features for LDA...
# done in 0.070s.
#
# Fitting LDA models with tf features, n_features=4100...
# done in 2.254s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food service farmer local agriculture farm young woman sustainable rural develop management order
# Topic #1: product produce food farmer natural fish production market fresh farm fruit vegetable pepper make tilapia tomato organic feed range package
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4100, 'doc_topic_prior': None}
# precision 89.20863309352518
# Extracting tf features for LDA...
# done in 0.064s.
#
# Fitting LDA models with tf features, n_features=4200...
# done in 1.545s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable rural develop management order
# Topic #1: farmer breed product president tel recreation partner fish feed promoter ponds zou creation entrepreneures presentation pond council régional email address
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4200, 'doc_topic_prior': None}
# precision 98.41726618705036
# Extracting tf features for LDA...
# done in 0.065s.
#
# Fitting LDA models with tf features, n_features=4300...
# done in 1.424s.
#
# Topics in LDA model:
# Topic #0: en creation farmer recreation ponds les zou loaf cayenne product allada entrepreneures régional conseil tel agricoles drop collines rb pineapple
# Topic #1: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable develop rural management order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4300, 'doc_topic_prior': None}
# precision 1.870503597122302
# Extracting tf features for LDA...
# done in 0.067s.
#
# Fitting LDA models with tf features, n_features=4400...
# done in 2.448s.
#
# Topics in LDA model:
# Topic #0: product production market food produce make agricultural create farmer farm local woman agriculture sustainable young rural organic service fruit vegetable
# Topic #1: service platform information create market make digital management product agricultural develop farmer social communication field mobile team access young technology
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4400, 'doc_topic_prior': None}
# precision 79.28057553956835
# Extracting tf features for LDA...
# done in 0.068s.
#
# Fitting LDA models with tf features, n_features=4500...
# done in 1.797s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food service farmer local agriculture farm young woman sustainable develop rural management order
# Topic #1: breed egg zou presentation farmer hen market tilapia chicken fish feed product creation farm lay young partner chickens chick pond
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4500, 'doc_topic_prior': None}
# precision 96.97841726618705
# Extracting tf features for LDA...
# done in 0.065s.
#
# Fitting LDA models with tf features, n_features=4600...
# done in 1.352s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable rural develop management order
# Topic #1: régional ponds recreation entrepreneures agricoles conseil zou collines product tel breed email une pond president promoter council farmer en tilapia
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4600, 'doc_topic_prior': None}
# precision 98.41726618705036
# Extracting tf features for LDA...
# done in 0.198s.
#
# Fitting LDA models with tf features, n_features=4700...
# done in 5.316s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable rural develop management order
# Topic #1: régional ponds recreation entrepreneures agricoles conseil zou collines product tel breed email une pond president promoter council farmer en tilapia
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4700, 'doc_topic_prior': None}
# precision 98.41726618705036
# Extracting tf features for LDA...
# done in 0.072s.
#
# Fitting LDA models with tf features, n_features=4800...
# done in 1.480s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable rural develop management order
# Topic #1: régional ponds recreation entrepreneures agricoles conseil zou collines product tel breed email une pond president promoter council farmer en tilapia
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4800, 'doc_topic_prior': None}
# precision 98.41726618705036
# Extracting tf features for LDA...
# done in 0.071s.
#
# Fitting LDA models with tf features, n_features=4900...
# done in 1.622s.
#
# Topics in LDA model:
# Topic #0: product market production make create agricultural produce food farmer service local farm agriculture young woman sustainable rural develop management order
# Topic #1: régional ponds recreation entrepreneures agricoles conseil zou collines product tel breed email une pond president promoter council farmer en tilapia
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4900, 'doc_topic_prior': None}
# precision 98.41726618705036

# %%
result_priors.sort_values('precision', ascending = False)
# Out:
#     n_components  n_top_words  n_features  doc_topic_prior  precision  \
# 0              2           20       20000                1  97.410072
# 1              2           20       20000                2  87.050360
# 2              2           20       20000                3  71.223022
# 3              2           20       20000                4  59.280576
# 4              2           20       20000                5  52.949640
# ..           ...          ...         ...              ...        ...
# 24             2           20       20000               25  39.856115
# 20             2           20       20000               21  39.856115
# 21             2           20       20000               22  39.712230
# 22             2           20       20000               23  39.712230
# 23             2           20       20000               24  39.712230
#
#                                           vocabulaire
# 0   [ab, abandon, abc, abeokuta, ability, abomeyca...
# 1   [ab, abandon, abc, abeokuta, ability, abomeyca...
# 2   [ab, abandon, abc, abeokuta, ability, abomeyca...
# 3   [ab, abandon, abc, abeokuta, ability, abomeyca...
# 4   [ab, abandon, abc, abeokuta, ability, abomeyca...
# ..                                                ...
# 24  [ab, abandon, abc, abeokuta, ability, abomeyca...
# 20  [ab, abandon, abc, abeokuta, ability, abomeyca...
# 21  [ab, abandon, abc, abeokuta, ability, abomeyca...
# 22  [ab, abandon, abc, abeokuta, ability, abomeyca...
# 23  [ab, abandon, abc, abeokuta, ability, abomeyca...
#
# [99 rows x 6 columns]

# %%
results_n_features.sort_values('precision', ascending = False)
# Out:
#     n_components  n_top_words  n_features doc_topic_prior  precision  \
# 25             2           20        3000            None  98.848921
# 16             2           20        2100            None  98.705036
# 44             2           20        4900            None  98.417266
# 37             2           20        4200            None  98.417266
# 43             2           20        4800            None  98.417266
# 42             2           20        4700            None  98.417266
# 41             2           20        4600            None  98.417266
# 9              2           20        1400            None  98.417266
# 21             2           20        2600            None  97.985612
# 33             2           20        3800            None  97.841727
# 7              2           20        1200            None  97.697842
# 35             2           20        4000            None  97.410072
# 29             2           20        3400            None  97.266187
# 40             2           20        4500            None  96.978417
# 30             2           20        3500            None  95.971223
# 32             2           20        3700            None  94.676259
# 36             2           20        4100            None  89.208633
# 19             2           20        2400            None  87.338129
# 39             2           20        4400            None  79.280576
# 10             2           20        1500            None  78.848921
# 8              2           20        1300            None  73.669065
# 6              2           20        1100            None  52.086331
# 12             2           20        1700            None  46.043165
# 22             2           20        2700            None  43.165468
# 0              2           20         500            None  39.136691
# 14             2           20        1900            None  31.510791
# 1              2           20         600            None  30.503597
# 5              2           20        1000            None  29.496403
# 11             2           20        1600            None  27.769784
# 31             2           20        3600            None  26.618705
# 4              2           20         900            None  26.474820
# 2              2           20         700            None  20.863309
# 15             2           20        2000            None  13.525180
# 20             2           20        2500            None   8.057554
# 18             2           20        2300            None   4.604317
# 23             2           20        2800            None   4.028777
# 26             2           20        3100            None   3.597122
# 17             2           20        2200            None   2.446043
# 27             2           20        3200            None   1.870504
# 38             2           20        4300            None   1.870504
# 34             2           20        3900            None   1.726619
# 3              2           20         800            None   1.582734
# 13             2           20        1800            None   1.438849
# 28             2           20        3300            None   1.151079
# 24             2           20        2900            None   1.151079
#
#                                           vocabulaire
# 25  [abandon, abeokuta, ability, abroad, absorb, a...
# 16  [abandon, ability, abroad, academic, academy, ...
# 44  [ab, abandon, abc, abeokuta, ability, abomeyca...
# 37  [ab, abandon, abc, abeokuta, ability, abroad, ...
# 43  [ab, abandon, abc, abeokuta, ability, abomeyca...
# 42  [ab, abandon, abc, abeokuta, ability, abomeyca...
# 41  [ab, abandon, abc, abeokuta, ability, abomeyca...
# 9   [ability, abroad, access, accessibility, acces...
# 21  [abandon, ability, abroad, abundance, abundant...
# 33  [ab, abandon, abeokuta, ability, abroad, absor...
# 7   [ability, abroad, access, accessible, accompan...
# 35  [ab, abandon, abc, abeokuta, ability, abroad, ...
# 29  [ab, abandon, abeokuta, ability, abroad, absor...
# 40  [ab, abandon, abc, abeokuta, ability, abomeyca...
# 30  [ab, abandon, abeokuta, ability, abroad, absor...
# 32  [ab, abandon, abeokuta, ability, abroad, absor...
# 36  [ab, abandon, abc, abeokuta, ability, abroad, ...
# 19  [abandon, ability, abroad, abundance, abundant...
# 39  [ab, abandon, abc, abeokuta, ability, abomeyca...
# 10  [abandon, ability, abroad, access, accessibili...
# 8   [ability, abroad, access, accessibility, acces...
# 6   [ability, abroad, access, accessible, accompan...
# 12  [abandon, ability, abroad, academic, accelerat...
# 22  [abandon, abeokuta, ability, abroad, abundance...
# 0   [access, accessible, accompany, account, acqui...
# 14  [abandon, ability, abroad, academic, accelerat...
# 1   [access, accessible, accompany, account, acqui...
# 5   [ability, abroad, access, accessible, accompan...
# 11  [abandon, ability, abroad, accelerate, access,...
# 31  [ab, abandon, abeokuta, ability, abroad, absor...
# 4   [ability, abroad, access, accessible, accompan...
# 2   [ability, access, accessible, accompany, accou...
# 15  [abandon, ability, abroad, academic, academy, ...
# 20  [abandon, ability, abroad, abundance, abundant...
# 18  [abandon, ability, abroad, abundance, abundant...
# 23  [abandon, abeokuta, ability, abroad, abundance...
# 26  [abandon, abeokuta, ability, abroad, absorb, a...
# 17  [abandon, ability, abroad, abundance, abundant...
# 27  [abandon, abeokuta, ability, abroad, absorb, a...
# 38  [ab, abandon, abc, abeokuta, ability, abomeyca...
# 34  [ab, abandon, abeokuta, ability, abroad, absor...
# 3   [ability, abroad, access, accessible, accompan...
# 13  [abandon, ability, abroad, academic, accelerat...
# 28  [abandon, abeokuta, ability, abroad, absorb, a...
# 24  [abandon, abeokuta, ability, abroad, absorb, a...

# %%
def perf_lda(model_parameters,train, test):
    def get_topic(e):
        if e >0:
            return 'agriculture'
        if e<0:
            return 'media'
    
    def true_positve(a,b):
        if a == b:
            return 1
        else:
            return 0
    model = model_lib.Models(**model_parameters)

    models = model.run_model_LDA(train.values.tolist())

    predict = pandas.DataFrame(model.reverse_lda(test.values.tolist(), models) , index =test.index)
    #display(predict)

    predict = predict.join(df['categorie'])
    predict[0] = predict[0]*100
    predict[1] = predict[1]*100
    predict['topic'] = predict[0]-predict[1]
    #display(predict)

    predict['predict_label'] = predict['topic'].map(get_topic)
    #display(predict)

    predict['classification_kpi'] = predict.apply(lambda x: true_positve(x['categorie'],x['predict_label']), axis= 1)
    #display(predict)

    agri = predict[predict['categorie'] == 'agriculture']
    print(model_parameters)
    print('precision {}'.format(agri['classification_kpi'].sum()/len(agri)*100))
    model_parameters.update({'precision':agri['classification_kpi'].sum()/len(agri)*100, 'vocabulaire': models['LDA']['feature_names']})
    errors = agri[agri['classification_kpi'] == 0].sort_values('topic')
    collections.Counter(' '.join(errors.join(text_corpus)['collection_counter'].values.tolist()).split()).most_common(10)
    return model_parameters

# %%
from sklearn.model_selection import train_test_split

test,train = train_test_split(text_corpus_label, test_size = 0.2)

print(len(text_corpus), len(test), len(train))

display(train.groupby('categorie').count())

display(text_corpus_label.groupby('categorie').count())

train = train['collection_counter']
test = test['collection_counter']
model_parameters = {'n_components' : 2, 'n_top_words' : 20, 'n_features' : 20000}
_ = perf_lda(model_parameters, train, test)
# Out:
# 787 629 158
#              collection_counter
# categorie
# agriculture                 143
# media                        15
#              collection_counter
# categorie
# agriculture                 695
# media                        92
# Extracting tf features for LDA...
# done in 0.068s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 1.031s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000}
# precision 97.64492753623189

# %%
list_model_parameters_prior = [{'n_components' : 2, 'n_top_words' : 20, 'n_features' : 20000, 'doc_topic_prior':alpha} for alpha in range(1,100,1)]

list_run = []
for model_parameters in list_model_parameters_prior:
    list_run.append(perf_lda(model_parameters, train, test))
result_priors = pandas.DataFrame(list_run).sort_values('precision', ascending = False)
# Out:
# Extracting tf features for LDA...
# done in 0.045s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.976s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm agriculture social farmer develop local management rural community promote
# Topic #1: farmer product food farm make service produce production create order market platform mobile directly access application web agricultural waste agriculture
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 1}
# precision 95.47101449275362
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.631s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make production produce market create agricultural order mobile agriculture access rural local platform feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 2}
# precision 85.32608695652173
# Extracting tf features for LDA...
# done in 0.020s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.539s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural young produce service social agriculture farm develop management local job community rural farmer
# Topic #1: product farmer food service farm make production create market produce agricultural agriculture order mobile local rural access feed promote plant
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 3}
# precision 74.27536231884058
# Extracting tf features for LDA...
# done in 0.022s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.734s.
#
# Topics in LDA model:
# Topic #0: product market make production create agricultural food produce young service social farm agriculture develop management local community farmer rural job
# Topic #1: product farmer food service make create farm production market produce agricultural agriculture local rural mobile order access promote management develop
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 4}
# precision 66.30434782608695
# Extracting tf features for LDA...
# done in 0.022s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.545s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural produce young service social farm agriculture develop farmer local management community rural job
# Topic #1: product farmer food service create make production market farm produce agricultural agriculture local rural mobile order access management promote develop
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 5}
# precision 62.68115942028986
# Extracting tf features for LDA...
# done in 0.020s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.431s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural produce young service farm social agriculture farmer develop local community management rural job
# Topic #1: product food farmer service create make production market farm produce agricultural agriculture local rural mobile order management develop promote access
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 6}
# precision 61.050724637681164
# Extracting tf features for LDA...
# done in 0.037s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.561s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce service young farm social farmer agriculture develop local community management rural job
# Topic #1: product food farmer service create make production market farm produce agricultural agriculture local rural management mobile order develop promote young
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 7}
# precision 59.05797101449275
# Extracting tf features for LDA...
# done in 0.023s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.402s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce service young farm social farmer agriculture develop local community rural management order
# Topic #1: product food service farmer create make production market farm produce agricultural agriculture local rural management develop mobile order young promote
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 8}
# precision 58.152173913043484
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.355s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce service young farm farmer social agriculture develop local community rural management order
# Topic #1: product food service farmer create make production market farm produce agricultural agriculture local rural management develop young mobile promote order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 9}
# precision 57.2463768115942
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.385s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce service young farm farmer social agriculture develop local community rural management order
# Topic #1: product food service farmer create make production market farm produce agricultural agriculture local rural management develop young mobile promote order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 10}
# precision 56.70289855072463
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.277s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce service farm young farmer social agriculture develop local community rural management order
# Topic #1: product food service farmer create make production market farm produce agricultural agriculture local rural management develop young promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 11}
# precision 55.434782608695656
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.273s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce service farm young farmer social agriculture develop local community rural management order
# Topic #1: product food service farmer create make production market farm produce agricultural agriculture local rural management develop young promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 12}
# precision 54.528985507246375
# Extracting tf features for LDA...
# done in 0.032s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.401s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce service farm young farmer social agriculture develop local community rural order management
# Topic #1: product food service farmer create make production market farm produce agricultural agriculture local rural management young develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 13}
# precision 54.710144927536234
# Extracting tf features for LDA...
# done in 0.021s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.246s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce service farm young farmer social agriculture develop local community rural order management
# Topic #1: product food service farmer create make production market farm produce agricultural agriculture local rural management young develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 14}
# precision 54.891304347826086
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.303s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce service farm young farmer social agriculture develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 15}
# precision 54.710144927536234
# Extracting tf features for LDA...
# done in 0.023s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.524s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young social agriculture develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 16}
# precision 54.891304347826086
# Extracting tf features for LDA...
# done in 0.040s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.412s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young social agriculture develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 17}
# precision 55.97826086956522
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.278s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 18}
# precision 56.15942028985508
# Extracting tf features for LDA...
# done in 0.050s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.308s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 19}
# precision 56.34057971014492
# Extracting tf features for LDA...
# done in 0.020s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.291s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 20}
# precision 56.88405797101449
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.560s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 21}
# precision 56.88405797101449
# Extracting tf features for LDA...
# done in 0.013s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.171s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 22}
# precision 56.70289855072463
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.178s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 23}
# precision 56.88405797101449
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.164s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 24}
# precision 56.70289855072463
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.160s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 25}
# precision 56.52173913043478
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.193s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 26}
# precision 56.15942028985508
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.153s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 27}
# precision 56.15942028985508
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.185s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 28}
# precision 55.97826086956522
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.154s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 29}
# precision 55.97826086956522
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.157s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 30}
# precision 55.97826086956522
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.147s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 31}
# precision 56.34057971014492
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.155s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 32}
# precision 56.34057971014492
# Extracting tf features for LDA...
# done in 0.028s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.172s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 33}
# precision 56.52173913043478
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.156s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 34}
# precision 56.52173913043478
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.148s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 35}
# precision 56.52173913043478
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.148s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 36}
# precision 56.34057971014492
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.153s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 37}
# precision 56.34057971014492
# Extracting tf features for LDA...
# done in 0.013s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.149s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 38}
# precision 56.34057971014492
# Extracting tf features for LDA...
# done in 0.021s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.156s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 39}
# precision 56.52173913043478
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.145s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 40}
# precision 56.52173913043478
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.143s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 41}
# precision 56.34057971014492
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.154s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 42}
# precision 56.34057971014492
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.136s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 43}
# precision 56.34057971014492
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.144s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 44}
# precision 56.52173913043478
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.150s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 45}
# precision 56.52173913043478
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.133s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 46}
# precision 56.52173913043478
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.143s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 47}
# precision 56.52173913043478
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.172s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 48}
# precision 56.52173913043478
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.133s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 49}
# precision 56.52173913043478
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.134s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 50}
# precision 56.52173913043478
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.143s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local rural young management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 51}
# precision 56.52173913043478
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.149s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm service farmer young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 52}
# precision 56.34057971014492
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.135s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 53}
# precision 56.15942028985508
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.127s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 54}
# precision 56.15942028985508
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.137s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 55}
# precision 56.15942028985508
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.133s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 56}
# precision 55.97826086956522
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.127s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 57}
# precision 55.97826086956522
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.135s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural management develop promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 58}
# precision 55.97826086956522
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.128s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 59}
# precision 55.97826086956522
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.129s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 60}
# precision 55.97826086956522
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.140s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 61}
# precision 55.97826086956522
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.136s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 62}
# precision 55.97826086956522
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.129s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 63}
# precision 55.97826086956522
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.126s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 64}
# precision 55.97826086956522
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.128s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 65}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.124s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 66}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.132s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 67}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.131s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 68}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.127s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 69}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.119s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 70}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.122s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 71}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.128s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 72}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.122s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 73}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.124s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 74}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.126s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 75}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.135s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 76}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.024s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.169s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 77}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.127s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 78}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.137s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create farmer make production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 79}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.127s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 80}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.130s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 81}
# precision 55.79710144927537
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.149s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 82}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.117s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 83}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.119s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 84}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.123s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 85}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.119s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 86}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.125s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 87}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.113s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 88}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.116s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 89}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.113s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 90}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.113s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 91}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.117s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 92}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.116s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 93}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.112s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 94}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.127s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 95}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.114s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 96}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.118s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 97}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.114s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 98}
# precision 55.61594202898551
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.114s.
#
# Topics in LDA model:
# Topic #0: product market make production food agricultural create produce farm farmer service young agriculture social develop local community rural order management
# Topic #1: product food service create make farmer production market farm produce agricultural agriculture local young rural develop management promote mobile order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000, 'doc_topic_prior': 99}
# precision 55.61594202898551

# %%
list_model_parameters_nfeatures = [{'n_components' : 2, 'n_top_words' : 20, 'n_features' : n_features, 'doc_topic_prior':None} for n_features in range(500,5000,100)]

list_run = []
for model_parameters in list_model_parameters_nfeatures:
    list_run.append(perf_lda(model_parameters,train, test))
results_n_features = pandas.DataFrame(list_run).sort_values('precision', ascending = False)
# Out:
# Extracting tf features for LDA...
# done in 0.136s.
#
# Fitting LDA models with tf features, n_features=500...
# done in 0.596s.
#
# Topics in LDA model:
# Topic #0: make product food agriculture farm market create association produce require production farmer training fruit field agricultural sustainable chicken powder young
# Topic #1: product market make food production create service agricultural farmer produce farm agriculture young local develop rural management social order promote
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 500, 'doc_topic_prior': None}
# precision 0.18115942028985507
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=600...
# done in 0.526s.
#
# Topics in LDA model:
# Topic #0: create market service digital design creative establish organisation online innovation computer respect event field exchange access individual maintain make develop
# Topic #1: product make food market production create farmer agricultural service produce farm agriculture young local rural develop social management order community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 600, 'doc_topic_prior': None}
# precision 0.18115942028985507
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=700...
# done in 2.366s.
#
# Topics in LDA model:
# Topic #0: platform farmer online make food direct service list share farm search product develop access agricultural message stage data deliver community
# Topic #1: product market production make create food service agricultural produce farmer farm agriculture young rural management social local develop promote order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 700, 'doc_topic_prior': None}
# precision 0.18115942028985507
# Extracting tf features for LDA...
# done in 0.094s.
#
# Fitting LDA models with tf features, n_features=800...
# done in 1.237s.
#
# Topics in LDA model:
# Topic #0: product farm market farmer make produce food create agricultural service community sustainable order register production young resource rural crop plant
# Topic #1: product production food make create service market agricultural agriculture develop produce young local farmer management promote rural social design individual
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 800, 'doc_topic_prior': None}
# precision 20.108695652173914
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=900...
# done in 0.540s.
#
# Topics in LDA model:
# Topic #0: bring entertainment life talent leader ceo chief financial product request useful forward presently street make food create farm market service
# Topic #1: product market make food production create service agricultural farmer produce farm agriculture young local develop rural management social order promote
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 900, 'doc_topic_prior': None}
# precision 0.0
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=1000...
# done in 0.644s.
#
# Topics in LDA model:
# Topic #0: market create digital product make design service mobile agricultural event farmer organisation contact creative develop order web field graphic production
# Topic #1: product food make production market create service agricultural farmer farm produce agriculture young local social rural develop management community promote
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1000, 'doc_topic_prior': None}
# precision 0.18115942028985507
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1100...
# done in 0.558s.
#
# Topics in LDA model:
# Topic #0: food online product platform make farmer deliver direct mobile access create affordable production search list service share request message order
# Topic #1: product market make production create food agricultural service farm produce farmer agriculture local young rural develop social management promote order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1100, 'doc_topic_prior': None}
# precision 0.7246376811594203
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1200...
# done in 0.664s.
#
# Topics in LDA model:
# Topic #0: product market food make production farmer farm agricultural create service produce agriculture local rural young order community management promote develop
# Topic #1: create social make production service product operate group young agricultural market develop benefit food association school daily produce management energy
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1200, 'doc_topic_prior': None}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.020s.
#
# Fitting LDA models with tf features, n_features=1300...
# done in 0.817s.
#
# Topics in LDA model:
# Topic #0: product market make production create service food agricultural farmer produce farm young agriculture local rural order develop promote social community
# Topic #1: product food farm make water farmer produce production create market management plant solar agricultural agriculture power vegetable material data building
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1300, 'doc_topic_prior': None}
# precision 98.18840579710145
# Extracting tf features for LDA...
# done in 0.023s.
#
# Fitting LDA models with tf features, n_features=1400...
# done in 0.611s.
#
# Topics in LDA model:
# Topic #0: product make market food production create service farmer agricultural produce farm agriculture young local rural develop management social order promote
# Topic #1: product create production food service market association agricultural womens make vegetable natural transformation social protection nutritional develop promote group rich
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1400, 'doc_topic_prior': None}
# precision 99.27536231884058
# Extracting tf features for LDA...
# done in 0.024s.
#
# Fitting LDA models with tf features, n_features=1500...
# done in 1.123s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1500, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.021s.
#
# Fitting LDA models with tf features, n_features=1600...
# done in 0.782s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1600, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1700...
# done in 0.613s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1700, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1800...
# done in 0.632s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1800, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=1900...
# done in 0.945s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1900, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.026s.
#
# Fitting LDA models with tf features, n_features=2000...
# done in 0.933s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2000, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.022s.
#
# Fitting LDA models with tf features, n_features=2100...
# done in 0.868s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2100, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.021s.
#
# Fitting LDA models with tf features, n_features=2200...
# done in 1.005s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2200, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=2300...
# done in 0.607s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2300, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2400...
# done in 0.613s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2400, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2500...
# done in 0.607s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2500, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=2600...
# done in 0.628s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2600, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.019s.
#
# Fitting LDA models with tf features, n_features=2700...
# done in 0.678s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2700, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.024s.
#
# Fitting LDA models with tf features, n_features=2800...
# done in 0.648s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2800, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=2900...
# done in 0.632s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2900, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3000...
# done in 0.639s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3000, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3100...
# done in 0.614s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3100, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3200...
# done in 0.601s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3200, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3300...
# done in 0.677s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3300, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3400...
# done in 0.633s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3400, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3500...
# done in 0.640s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3500, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=3600...
# done in 0.670s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3600, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3700...
# done in 0.645s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3700, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=3800...
# done in 0.640s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3800, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3900...
# done in 0.649s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3900, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=4000...
# done in 0.607s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4000, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=4100...
# done in 0.590s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4100, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=4200...
# done in 0.618s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4200, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4300...
# done in 0.648s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4300, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4400...
# done in 0.613s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4400, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=4500...
# done in 0.625s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4500, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=4600...
# done in 0.606s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4600, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=4700...
# done in 0.635s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4700, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=4800...
# done in 0.616s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4800, 'doc_topic_prior': None}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4900...
# done in 0.621s.
#
# Topics in LDA model:
# Topic #0: product market production make create food agricultural service produce young farm farmer agriculture social develop local management rural job promote
# Topic #1: farmer product food make farm service produce production directly platform order create waste packaging feed access web market advice application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4900, 'doc_topic_prior': None}
# precision 97.64492753623189

# %%
list_model_parameters_nfeatures = [{'n_components' : 2, 'n_top_words' : 20, 'n_features' : n_features, 'doc_topic_prior':alpha/10} for alpha in range(1,100,1) for n_features in range(500,5000,100)]

list_run = []
for model_parameters in list_model_parameters_nfeatures:
    list_run.append(perf_lda(model_parameters,train, test))
results = pandas.DataFrame(list_run).sort_values('precision', ascending = False)
results.sort_values('precision', ascending = False)
# Out:
# Extracting tf features for LDA...
# done in 0.054s.
#
# Fitting LDA models with tf features, n_features=500...
# done in 0.414s.
#
# Topics in LDA model:
# Topic #0: farm product make food agriculture market association create chicken powder health service machine poultry restaurant produce require capital farmer production
# Topic #1: product market make food production create service agricultural farmer produce farm agriculture young local develop rural management social order promote
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 500, 'doc_topic_prior': 0.1}
# precision 0.18115942028985507
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=600...
# done in 0.302s.
#
# Topics in LDA model:
# Topic #0: make develop access exchange platform mobile app share organisation online search network contact connect list professional external continue feature direct
# Topic #1: product market make food production create service agricultural farmer produce farm agriculture young local rural management social develop order community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 600, 'doc_topic_prior': 0.1}
# precision 0.18115942028985507
# Extracting tf features for LDA...
# done in 0.026s.
#
# Fitting LDA models with tf features, n_features=700...
# done in 0.391s.
#
# Topics in LDA model:
# Topic #0: make farmer platform list farm online service share direct food agricultural young develop community local connect access data exchange water
# Topic #1: product market production make food create service agricultural produce farmer farm agriculture young management rural social local order develop promote
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 700, 'doc_topic_prior': 0.1}
# precision 0.7246376811594203
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=800...
# done in 0.444s.
#
# Topics in LDA model:
# Topic #0: product market farmer make farm food service create produce agricultural community production group order young social resource rural sustainable web
# Topic #1: product production food make create market agricultural service agriculture produce local develop promote young management farmer rural farm job organic
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 800, 'doc_topic_prior': 0.1}
# precision 35.507246376811594
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=900...
# done in 0.253s.
#
# Topics in LDA model:
# Topic #0: bring life talent leader ceo entertainment chief financial useful request forward street presently product make create improvement market farm food
# Topic #1: product market make food production create service agricultural farmer produce farm agriculture young local develop rural management social order promote
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 900, 'doc_topic_prior': 0.1}
# precision 0.0
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=1000...
# done in 0.334s.
#
# Topics in LDA model:
# Topic #0: market create digital make design product service mobile agricultural organisation creative event develop contact graphic farmer production application order plant
# Topic #1: product food make production market create service farmer agricultural produce farm agriculture young local rural social develop community management promote
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1000, 'doc_topic_prior': 0.1}
# precision 0.18115942028985507
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1100...
# done in 0.354s.
#
# Topics in LDA model:
# Topic #0: product food online platform make affordable farmer direct deliver access mobile create search share list vegetable production message service web
# Topic #1: product market make production create food agricultural service produce farm farmer agriculture local young rural social develop management promote order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1100, 'doc_topic_prior': 0.1}
# precision 0.5434782608695652
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=1200...
# done in 0.379s.
#
# Topics in LDA model:
# Topic #0: product market food make production farmer create farm agricultural service produce agriculture local young order rural community management develop promote
# Topic #1: create make social service production group operate product food young agricultural benefit develop daily association market school produce energy urban
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1200, 'doc_topic_prior': 0.1}
# precision 98.91304347826086
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=1300...
# done in 1.406s.
#
# Topics in LDA model:
# Topic #0: product market make food service production create farmer agricultural produce rural farm young community woman develop local agriculture social individual
# Topic #1: product production create farm produce food make agriculture agricultural water management market farmer vegetable plant crop promote service job organic
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1300, 'doc_topic_prior': 0.1}
# precision 82.42753623188406
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=1400...
# done in 0.588s.
#
# Topics in LDA model:
# Topic #0: product market make food production create service farmer agricultural produce farm agriculture young local rural develop management social order promote
# Topic #1: life bring product forward financial leader ceo letter talent presently officer street assistance production useful chief entertainment request food create
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1400, 'doc_topic_prior': 0.1}
# precision 99.09420289855072
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1500...
# done in 0.449s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1500, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=1600...
# done in 0.462s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1600, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1700...
# done in 0.433s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1700, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=1800...
# done in 0.423s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1800, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=1900...
# done in 0.481s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1900, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=2000...
# done in 0.383s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2000, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=2100...
# done in 0.405s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2100, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2200...
# done in 0.419s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2200, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=2300...
# done in 0.416s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2300, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=2400...
# done in 0.403s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2400, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=2500...
# done in 0.398s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2500, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=2600...
# done in 0.433s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2600, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=2700...
# done in 0.400s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2700, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.019s.
#
# Fitting LDA models with tf features, n_features=2800...
# done in 0.532s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2800, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=2900...
# done in 0.399s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2900, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3000...
# done in 0.404s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3000, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.023s.
#
# Fitting LDA models with tf features, n_features=3100...
# done in 0.402s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3100, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3200...
# done in 0.413s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3200, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=3300...
# done in 0.497s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3300, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=3400...
# done in 0.399s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3400, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3500...
# done in 0.499s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3500, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3600...
# done in 0.420s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3600, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=3700...
# done in 0.424s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3700, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3800...
# done in 0.390s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3800, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=3900...
# done in 0.489s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3900, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=4000...
# done in 0.451s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4000, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4100...
# done in 0.419s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4100, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4200...
# done in 0.400s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4200, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=4300...
# done in 0.433s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4300, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4400...
# done in 0.425s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4400, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4500...
# done in 0.433s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4500, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=4600...
# done in 0.407s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4600, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4700...
# done in 0.405s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4700, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.020s.
#
# Fitting LDA models with tf features, n_features=4800...
# done in 0.433s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4800, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4900...
# done in 0.429s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product farm food make produce service production order create agricultural directly table platform crop web agriculture waste packaging scale
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4900, 'doc_topic_prior': 0.1}
# precision 97.64492753623189
# Extracting tf features for LDA...
# done in 0.019s.
#
# Fitting LDA models with tf features, n_features=500...
# done in 0.301s.
#
# Topics in LDA model:
# Topic #0: farm make product food agriculture market association create powder machine require chicken produce capital poultry farmer production digital supplier health
# Topic #1: product market make food production create service agricultural farmer produce farm agriculture young local develop rural management social order promote
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 500, 'doc_topic_prior': 0.2}
# precision 0.18115942028985507
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=600...
# done in 0.329s.
#
# Topics in LDA model:
# Topic #0: make develop exchange access platform mobile network share app organisation online search contact connect list professional continue external feature direct
# Topic #1: product market make food production create service agricultural farmer produce farm agriculture young local rural management social develop order community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 600, 'doc_topic_prior': 0.2}
# precision 0.18115942028985507
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=700...
# done in 0.390s.
#
# Topics in LDA model:
# Topic #0: make platform farmer list service online farm share direct food agricultural young develop community local access connect data exchange water
# Topic #1: product market production make food create service agricultural produce farmer farm agriculture young management rural social local order develop promote
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 700, 'doc_topic_prior': 0.2}
# precision 0.5434782608695652
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=800...
# done in 0.492s.
#
# Topics in LDA model:
# Topic #0: product market make farmer farm food service create produce agricultural production community social group order young rural resource sustainable city
# Topic #1: production product food create make market agricultural service agriculture produce local develop young promote management farmer rural job organic social
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 800, 'doc_topic_prior': 0.2}
# precision 42.7536231884058
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=900...
# done in 0.316s.
#
# Topics in LDA model:
# Topic #0: bring talent life leader ceo entertainment chief financial useful request forward street presently product make improvement create market farm food
# Topic #1: product market make food production create service agricultural farmer produce farm agriculture young local develop rural management social order promote
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 900, 'doc_topic_prior': 0.2}
# precision 0.0
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1000...
# done in 0.418s.
#
# Topics in LDA model:
# Topic #0: market create digital make design product service mobile agricultural creative organisation contact event develop farmer graphic order production web application
# Topic #1: product food make production market create service farmer agricultural produce farm agriculture young local rural social management develop community promote
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1000, 'doc_topic_prior': 0.2}
# precision 0.18115942028985507
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1100...
# done in 0.392s.
#
# Topics in LDA model:
# Topic #0: food online product platform make farmer direct deliver affordable access create mobile search share list production service message web order
# Topic #1: product market make production create food agricultural service farm produce farmer agriculture local young rural social develop management promote order
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1100, 'doc_topic_prior': 0.2}
# precision 0.5434782608695652
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=1200...
# done in 0.447s.
#
# Topics in LDA model:
# Topic #0: product market food make production farmer farm create agricultural service produce agriculture local young order rural community management develop promote
# Topic #1: create make social service production group product operate young food agricultural market benefit develop school association produce daily energy urban
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1200, 'doc_topic_prior': 0.2}
# precision 98.18840579710145
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1300...
# done in 0.508s.
#
# Topics in LDA model:
# Topic #0: product market make food production service create farmer agricultural produce farm rural young local community develop woman agriculture order social
# Topic #1: product create production food farm produce make water management agricultural agriculture market vegetable farmer plant promote service organic crop job
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1300, 'doc_topic_prior': 0.2}
# precision 88.04347826086956
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=1400...
# done in 0.340s.
#
# Topics in LDA model:
# Topic #0: product market make food production create service farmer agricultural produce farm agriculture young local rural develop management social order promote
# Topic #1: life product bring production forward ceo talent letter officer financial presently street leader assistance food useful create chief entertainment request
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1400, 'doc_topic_prior': 0.2}
# precision 99.27536231884058
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=1500...
# done in 0.442s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1500, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=1600...
# done in 0.455s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1600, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=1700...
# done in 0.460s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1700, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=1800...
# done in 0.451s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1800, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1900...
# done in 0.457s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1900, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2000...
# done in 0.463s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2000, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2100...
# done in 0.457s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2100, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2200...
# done in 0.464s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2200, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2300...
# done in 0.467s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2300, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=2400...
# done in 0.447s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2400, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2500...
# done in 0.460s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2500, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2600...
# done in 0.474s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2600, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=2700...
# done in 0.522s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2700, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2800...
# done in 0.583s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2800, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2900...
# done in 0.491s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2900, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3000...
# done in 0.467s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3000, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=3100...
# done in 0.480s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3100, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=3200...
# done in 0.506s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3200, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3300...
# done in 0.507s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3300, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=3400...
# done in 0.458s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3400, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=3500...
# done in 0.462s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3500, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3600...
# done in 0.478s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3600, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3700...
# done in 0.490s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3700, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=3800...
# done in 0.489s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3800, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3900...
# done in 0.578s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3900, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4000...
# done in 0.467s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4000, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4100...
# done in 0.466s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# Topic #1: farmer product food farm make produce service production directly order create agricultural platform crop web waste packaging advice feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4100, 'doc_topic_prior': 0.2}
# precision 98.0072463768116
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=4200...
# done in 0.469s.
#
# Topics in LDA model:
# Topic #0: product market make production create food service agricultural produce young farm farmer agriculture social local develop management rural community job
# ...
# precision 88.04347826086956
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4200...
# done in 0.660s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make produce production market create agricultural order mobile access agriculture rural platform local application feed
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4200, 'doc_topic_prior': 1.8}
# precision 88.04347826086956
# Extracting tf features for LDA...
# done in 0.019s.
#
# Fitting LDA models with tf features, n_features=4300...
# done in 0.661s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make produce production market create agricultural order mobile access agriculture rural platform local application feed
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4300, 'doc_topic_prior': 1.8}
# precision 88.04347826086956
# Extracting tf features for LDA...
# done in 0.020s.
#
# Fitting LDA models with tf features, n_features=4400...
# done in 0.917s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make produce production market create agricultural order mobile access agriculture rural platform local application feed
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4400, 'doc_topic_prior': 1.8}
# precision 88.04347826086956
# Extracting tf features for LDA...
# done in 0.063s.
#
# Fitting LDA models with tf features, n_features=4500...
# done in 1.743s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make produce production market create agricultural order mobile access agriculture rural platform local application feed
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4500, 'doc_topic_prior': 1.8}
# precision 88.04347826086956
# Extracting tf features for LDA...
# done in 0.019s.
#
# Fitting LDA models with tf features, n_features=4600...
# done in 0.887s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make produce production market create agricultural order mobile access agriculture rural platform local application feed
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4600, 'doc_topic_prior': 1.8}
# precision 88.04347826086956
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=4700...
# done in 0.638s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make produce production market create agricultural order mobile access agriculture rural platform local application feed
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4700, 'doc_topic_prior': 1.8}
# precision 88.04347826086956
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=4800...
# done in 0.721s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make produce production market create agricultural order mobile access agriculture rural platform local application feed
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4800, 'doc_topic_prior': 1.8}
# precision 88.04347826086956
# Extracting tf features for LDA...
# done in 0.021s.
#
# Fitting LDA models with tf features, n_features=4900...
# done in 0.719s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make produce production market create agricultural order mobile access agriculture rural platform local application feed
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4900, 'doc_topic_prior': 1.8}
# precision 88.04347826086956
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=500...
# done in 0.535s.
#
# Topics in LDA model:
# Topic #0: make food product farm market create farmer agriculture produce service production agricultural affordable develop fruit community rural water natural vegetable
# Topic #1: product market production create make service food agricultural farmer produce farm young local agriculture management social order promote rural develop
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 500, 'doc_topic_prior': 1.9}
# precision 5.434782608695652
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=600...
# done in 0.525s.
#
# Topics in LDA model:
# Topic #0: market product create service production agricultural digital food farmer make design produce agriculture young local promote online order management rural
# Topic #1: product make food market production create farmer farm produce service agricultural agriculture young social develop community local rural management job
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 600, 'doc_topic_prior': 1.9}
# precision 5.978260869565218
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=700...
# done in 0.668s.
#
# Topics in LDA model:
# Topic #0: food service product make farmer production create develop platform agricultural local farm online access community data market direct produce young
# Topic #1: product market production make create food agricultural produce farmer farm service agriculture young management rural social order promote local job
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 700, 'doc_topic_prior': 1.9}
# precision 12.5
# Extracting tf features for LDA...
# done in 0.021s.
#
# Fitting LDA models with tf features, n_features=800...
# done in 0.809s.
#
# Topics in LDA model:
# Topic #0: product market farm farmer make create food produce agricultural service production digital order plant rural local community agriculture management promote
# Topic #1: product production make food service create agricultural market produce develop agriculture young farmer local social rural management operate job water
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 800, 'doc_topic_prior': 1.9}
# precision 23.369565217391305
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=900...
# done in 0.575s.
#
# Topics in LDA model:
# Topic #0: product make food service create agricultural farmer operate production market bring farm distribution online mobile vegetable order life develop expert
# Topic #1: product market production make food create service agricultural produce farmer farm agriculture young local management rural develop social community promote
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 900, 'doc_topic_prior': 1.9}
# precision 0.9057971014492754
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1000...
# done in 0.663s.
#
# Topics in LDA model:
# Topic #0: product create make market service farmer produce production agricultural order design digital management food develop farm young life promote event
# Topic #1: product food production market make agricultural service farm farmer create agriculture produce young social local rural community develop management water
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1000, 'doc_topic_prior': 1.9}
# precision 6.159420289855073
# Extracting tf features for LDA...
# done in 0.031s.
#
# Fitting LDA models with tf features, n_features=1100...
# done in 0.700s.
#
# Topics in LDA model:
# Topic #0: product food make market service farmer create produce production social rural develop agricultural order platform deliver online mobile management web
# Topic #1: product market make production create agricultural farm food service farmer agriculture produce young local promote management plant develop rural community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1100, 'doc_topic_prior': 1.9}
# precision 4.528985507246377
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=1200...
# done in 0.667s.
#
# Topics in LDA model:
# Topic #0: product food make market farm farmer production produce service create agricultural agriculture local community rural access promote order woman young
# Topic #1: product production create market agricultural service young make social develop food management group produce operate farmer vegetable field order design
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1200, 'doc_topic_prior': 1.9}
# precision 85.68840579710145
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=1300...
# done in 0.672s.
#
# Topics in LDA model:
# Topic #0: product market service create make production agricultural food produce farmer order young rural agriculture farm local woman develop individual digital
# Topic #1: product food make farm production farmer market create agricultural produce management agriculture job local social develop young water vegetable service
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1300, 'doc_topic_prior': 1.9}
# precision 77.35507246376811
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1400...
# done in 0.530s.
#
# Topics in LDA model:
# Topic #0: product make market food production farmer create agricultural produce service farm agriculture young local rural management develop social order community
# Topic #1: create production product service market food make agricultural vegetable develop organization life promote job bring list social online sustainable water
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1400, 'doc_topic_prior': 1.9}
# precision 98.55072463768117
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=1500...
# done in 0.659s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make production produce market create agricultural order mobile agriculture access rural local platform feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1500, 'doc_topic_prior': 1.9}
# precision 86.41304347826086
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=1600...
# done in 0.704s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make production produce market create agricultural order mobile agriculture access rural local platform feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1600, 'doc_topic_prior': 1.9}
# precision 86.41304347826086
# Extracting tf features for LDA...
# done in 0.021s.
#
# Fitting LDA models with tf features, n_features=1700...
# done in 0.716s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make production produce market create agricultural order mobile agriculture access rural local platform feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1700, 'doc_topic_prior': 1.9}
# precision 86.41304347826086
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=1800...
# done in 0.642s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make production produce market create agricultural order mobile agriculture access rural local platform feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1800, 'doc_topic_prior': 1.9}
# precision 86.41304347826086
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=1900...
# done in 0.639s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make production produce market create agricultural order mobile agriculture access rural local platform feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1900, 'doc_topic_prior': 1.9}
# precision 86.41304347826086
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2000...
# done in 0.679s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make production produce market create agricultural order mobile agriculture access rural local platform feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2000, 'doc_topic_prior': 1.9}
# precision 86.41304347826086
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=2100...
# done in 0.683s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make production produce market create agricultural order mobile agriculture access rural local platform feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2100, 'doc_topic_prior': 1.9}
# precision 86.41304347826086
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2200...
# done in 0.644s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make production produce market create agricultural order mobile agriculture access rural local platform feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2200, 'doc_topic_prior': 1.9}
# precision 86.41304347826086
# Extracting tf features for LDA...
# done in 0.020s.
#
# Fitting LDA models with tf features, n_features=2300...
# done in 0.750s.
#
# Topics in LDA model:
# Topic #0: product market make production create food agricultural service young produce social agriculture farm develop management local job rural community promote
# Topic #1: product farmer food service farm make production produce market create agricultural order mobile agriculture access rural local platform feed application
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2300, 'doc_topic_prior': 1.9}
# precision 86.41304347826086
# Extracting tf features for LDA...
# done in 0.024s.
#
# Fitting LDA models with tf features, n_features=2400...

# %%
results.sort_values('doc_topic_prior')
# Out:
#       n_components  n_top_words  n_features  doc_topic_prior  precision  \
# 12               2           20        1700              0.1  97.644928
# 6                2           20        1100              0.1   0.543478
# 5                2           20        1000              0.1   0.181159
# 34               2           20        3900              0.1  97.644928
# 18               2           20        2300              0.1  97.644928
# ...            ...          ...         ...              ...        ...
# 4436             2           20        3100              9.9  56.702899
# 4435             2           20        3000              9.9  56.702899
# 4446             2           20        4100              9.9  56.702899
# 4423             2           20        1800              9.9  56.702899
# 4414             2           20         900              9.9  29.347826
#
#                                             vocabulaire
# 12    [ability, abroad, absorb, academic, access, ac...
# 6     [ability, abroad, absorb, access, accessibilit...
# 5     [ability, abroad, absorb, access, accessibilit...
# 34    [ability, abroad, absorb, academic, access, ac...
# 18    [ability, abroad, absorb, academic, access, ac...
# ...                                                 ...
# 4436  [ability, abroad, absorb, academic, access, ac...
# 4435  [ability, abroad, absorb, academic, access, ac...
# 4446  [ability, abroad, absorb, academic, access, ac...
# 4423  [ability, abroad, absorb, academic, access, ac...
# 4414  [ability, abroad, absorb, access, accessibilit...
#
# [4455 rows x 6 columns]

# %%
challenge =chalenge1000.Native().ALL
header = challenge.keys()#[['pays_struc1', 'pays_struc2']]
def reduce_dim_pays(element):
    return sorted(list(set(element.split('-----'))),key = lambda x: len(x), reverse = True)
challenge['pays'] = challenge['pays_struc1'].map(reduce_dim_pays)
challenge['pays2'] = challenge['pays_struc2'].map(reduce_dim_pays)
country = challenge[['pays','pays2']]

# %%
# Out:
# Index(['nom_struc', 'categorie', 'cat_struc', 'cat_autre_struc', 'age_pers',
#        'nbr_salarie', 'ca_2017', 'ca_2018', 'ca_2019', 'pays_struc1',
#        'date_struc', 'prix_struc', 'linkedin_struc', 'email_pers'],
#       dtype='object')

# %%
full_corpus = ' '.join(df[df['categorie'] == 'agriculture'][['nom_struc', 'categorie']].join(Chalenge.descriptions_trad)[['prez_struc', 'prez_produit_struc']].fillna('').agg(sum, axis=1).values.tolist())

full_corpus = model_lib.Lemm(X = full_corpus, file = 'stopwords_agri.txt').X

collections.Counter(full_corpus.split()).most_common(5000)

# %%
import chalenge1000
import pandas
from rake_nltk import Rake
import model_lib
C = chalenge1000.Native()
h = C.descriptions_trad
k = C.X
k = k[k['categorie'] == 'agriculture']
M = k.join(h)
M['description'] = M[['prez_struc', 'prez_produit_struc']].agg(sum, axis = 1)

# %%
import random
i = random.choice(range(0,698))

r= Rake()
t= M['description'].values.tolist()[i]
print(M['nom_struc'].values.tolist()[i])
print(t)
r.extract_keywords_from_text(t)
print(r.get_ranked_phrases_with_scores()[:5])
t_1 = model_lib.Lemm(X = t).H
r= Rake()
r.extract_keywords_from_text(t_1)
print(r.get_ranked_phrases_with_scores()[:5])
# Out:
# AGROPASE-CI
# The FERME D'ICI located in Sassandra in the south west of Ivory Coast is a project of the AGROPASE-CI structure. Created in 2018, the farm currently produces broilers and hybrids; it also plans to produce chickens of local breeds called bicycles. We regularly produce maize on an area of two hectares to feed the subjects and reduce our production load, which allows us to offer competitive products.With a view to contributing to the achievement of food security that will allow all people to have, at any time, the physical, social and economic opportunity to obtain sufficient, healthy and nutritious food in the region of Sassandra, Cote d'Ivoire and on our continent;our poultry project called "LA FERME D'ICI" buys by bands, chicks of meat breeds and hybrids which are treated and fed on the farm by a permanent poultry farmer using corn from our plantation combined with concentrated feed purchased with IVOGRAIN (industrialist manufacturer of cattle feed).Thanks to this strategy of composing natural and industrial feeds, the farm produces large broiler chickens of more than 2.5 kg in 45 days and large hybrid chickens of 2.5 kg after 70 days with an appetizing taste and a meat less infected by chemical inputs, therefore less dangerous for the health of the final consumers.
# [(24.0, 'permanent poultry farmer using corn'), (20.166666666666668, 'farm produces large broiler chickens'), (15.833333333333334, 'farm currently produces broilers'), (14.666666666666666, 'cattle feed ). thanks'), (14.5, 'local breeds called bicycles')]
# [(25.0, 'permanent poultry farmer using corn'), (24.0, 'chemical inputs therefore less dangerous'), (20.5, 'poultry project called la ferme'), (20.166666666666668, 'farm produces large broiler chickens'), (16.0, 'agropase ci structure created')]

# %%
r.extract_keywords_from_text(t)
print(r.get_ranked_phrases_with_scores())
t_1 = model_lib.Lemm(X = t).H
r= Rake()
r.extract_keywords_from_text(t_1)
print(r.get_ranked_phrases_with_scores())
# Out:
# [(44.0, 'small family owned agricultural export company aim'), (34.5, 'provide value added supply chain services'), (11.0, 'small scale farmers'), (10.5, 'make exportation services'), (10.0, 'food agricultural products'), (9.0, 'packaged livestock products'), (5.5, 'agricultural produce'), (4.0, 'snail meat'), (4.0, 'rural areas'), (4.0, 'imperishable cash'), (4.0, 'fresh tomatoes'), (3.5, 'well perserved'), (1.5, 'well'), (1.5, 'produce'), (1.0, 'world'), (1.0, 'selling'), (1.0, 'purchase'), (1.0, 'processed'), (1.0, 'perishable'), (1.0, 'nationally'), (1.0, 'international'), (1.0, 'farm'), (1.0, 'facilitating'), (1.0, 'connecting'), (1.0, 'coffee'), (1.0, 'cocoa'), (1.0, 'cameroon'), (1.0, 'buying'), (1.0, 'basically'), (1.0, 'bananas'), (1.0, 'atabong')]
# [(44.66666666666667, 'small family owned agricultural export company aim'), (34.5, 'provide value added supply chain services'), (25.0, 'cocoa coffee bananas fresh tomatoes'), (23.666666666666668, 'imperishable cash food agricultural products'), (11.0, 'small scale farmers'), (10.5, 'make exportation services'), (10.0, 'packaged livestock products'), (6.666666666666667, 'agricultural produce'), (4.0, 'snail meat'), (4.0, 'rural areas'), (4.0, 'produce purchase'), (4.0, 'international basically'), (3.5, 'well perserved'), (1.5, 'well'), (1.0, 'world'), (1.0, 'selling'), (1.0, 'processed'), (1.0, 'perishable'), (1.0, 'nationally'), (1.0, 'farm'), (1.0, 'facilitating'), (1.0, 'connecting'), (1.0, 'cameroon'), (1.0, 'buying'), (1.0, 'atabong')]

# %%
def rake_description(e):
    try:
        r= Rake()
        r.extract_keywords_from_text(e)
        return r.get_ranked_phrases_with_scores()
    except:
        return ''

# %%
M['rake'] = M['description'].map(rake_description)

l = M['rake'].values.tolist()

flat_list = [item for sublist in l for item in sublist]

flat_list = sorted(flat_list)[::-1]
import collections
collections.Counter([b for a,b in flat_list]).most_common(100)

# %%
M.keys()
# Out:
# Index(['nom_struc', 'categorie', 'cat_struc', 'cat_autre_struc', 'age_pers',
#        'nbr_salarie', 'ca_2017', 'ca_2018', 'ca_2019', 'pays_struc1',
#        'date_struc', 'prix_struc', 'linkedin_struc', 'email_pers',
#        'prez_struc', 'prez_produit_struc', 'prez_marche_struc',
#        'prez_zone_struc', 'prez_objectif_struc', 'prez_innovante_struc',
#        'prez_duplicable_struc', 'prez_durable_struc', 'description', 'rake'],
#       dtype='object')

# %%
from sklearn.metrics import homogeneity_completeness_v_measure, f1_score
homogeneity_completeness_v_measure(x,y)

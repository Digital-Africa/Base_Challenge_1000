# %%
from sklearn.model_selection import train_test_split
import chalenge1000
import model_lib
import collections
from IPython.display import display, HTML
import pandas


Chalenge = chalenge1000.Native()
df = Chalenge.X

# %%
def vocab(element):
    if type(element) == str:
        return ' '.join(set(element.split(' ')))
    else:
        return ''

def _agriculture__(element):
    if element in agriculture:
        return True
    else:
        return False
    
col_count = lambda x: ' '.join([a for a,b in collections.Counter(x.split()).most_common(10000)])

lemm = lambda x: model_lib.Lemm(x,file = 'stopwords_agri.txt').X

def df_fmt(df):
    df['corpus'] = df.join(Chalenge.descriptions_trad)[['prez_struc','prez_produit_struc']].agg(sum, axis = 1)
    df['type'] = df['corpus'].map(type)
    df['corpus'] = df['corpus'].map(vocab)
    df['corpus_lemm'] = df['corpus'].map(lemm)
    df['collection_counter'] = df['corpus_lemm'].map(col_count)
    agr = {e for e in df['cat_autre_struc'].dropna().values.tolist() if 'agr' in e}
    alim = {e for e in df['cat_autre_struc'].dropna().values.tolist() if 'alim' in e}
    agriculture = alim.union(agr)
    #df = df[df['type'] ==str]
    return df

def perf_lda(model_parameters,train, test):
    
    def get_topic(e):
        if e >0:
            return 'agriculture'
        if e<0:
            return 'media'
    
    def true_positve(a,b):
        if a == b:
            return 1
        else:
            return 0
        
    model = model_lib.Models(**model_parameters)

    models = model.run_model_LDA(train.values.tolist())

    predict = pandas.DataFrame(model.reverse_lda(test.values.tolist(), models) , index =test.index)
    #display(predict)

    predict = predict.join(df['categorie'])
    predict[0] = predict[0]*100
    predict[1] = predict[1]*100
    predict['topic'] = predict[0]-predict[1]
    #display(predict)

    predict['predict_label'] = predict['topic'].map(get_topic)
    #display(predict)

    predict['classification_kpi'] = predict.apply(lambda x: true_positve(x['categorie'],x['predict_label']), axis= 1)
    #display(predict)

    agri = predict[predict['categorie'] == 'agriculture']
    print(model_parameters)
    print('precision {}'.format(agri['classification_kpi'].sum()/len(agri)*100))
    model_parameters.update({'precision':agri['classification_kpi'].sum()/len(agri)*100, 'vocabulaire': models['LDA']['feature_names']})
    errors = agri[agri['classification_kpi'] == 0].sort_values('topic')
    collections.Counter(' '.join(errors.join(text_corpus)['collection_counter'].values.tolist()).split()).most_common(10)
    return model_parameters

# %%
df = df_fmt(df)

text_corpus = df[(df['categorie'].isin(['agriculture','media'])) & (df['type'] ==str)]['collection_counter']
text_corpus_label = df[df['categorie'].isin(['agriculture','media']) & (df['type'] ==str)][['categorie','collection_counter']]

# %%
test,train = train_test_split(text_corpus_label, test_size = 0.2)

print(len(text_corpus), len(test), len(train))

display(train.groupby('categorie').count())

display(text_corpus_label.groupby('categorie').count())

train = train['collection_counter']
test = test['collection_counter']
model_parameters = {'n_components' : 2, 'n_top_words' : 20, 'n_features' : 20000}
_ = perf_lda(model_parameters, train, test)
# Out:
# 787 629 158
#              collection_counter
# categorie
# agriculture                 141
# media                        17
#              collection_counter
# categorie
# agriculture                 695
# media                        92
# Extracting tf features for LDA...
# done in 0.030s.
#
# Fitting LDA models with tf features, n_features=20000...
# done in 0.551s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product energy renewable waste production service seed oil peanut paste market recycle produce plastic public create end cover transforms farm
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 20000}
# precision 99.27797833935018

# %%
list_model_parameters_nfeatures = [{'n_components' : 2, 'n_top_words' : 20, 'n_features' : n_features, 'doc_topic_prior':alpha/10} for alpha in range(1,100,1) for n_features in range(500,5000,100)]

list_run = []
for model_parameters in list_model_parameters_nfeatures:
    list_run.append(perf_lda(model_parameters,train, test))
results = pandas.DataFrame(list_run).sort_values('precision', ascending = False)
results.sort_values('precision', ascending = False)
# Out:
# Extracting tf features for LDA...
# done in 0.029s.
#
# Fitting LDA models with tf features, n_features=500...
# done in 0.384s.
#
# Topics in LDA model:
# Topic #0: service product water energy maintenance school technology sustainable rural make access cover oil create renewable digital equipment power environment sustainability
# Topic #1: product production create market local agricultural produce food farm farmer make social young fruit service group agriculture develop sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 500, 'doc_topic_prior': 0.1}
# precision 2.527075812274368
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=600...
# done in 0.353s.
#
# Topics in LDA model:
# Topic #0: create community rural local make market young social child information affordable organization knowledge access establish service maintenance technology sustainable strong
# Topic #1: product production market agricultural create service local food produce farm farmer make fruit sustainable group agriculture social young develop waste
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 600, 'doc_topic_prior': 0.1}
# precision 0.36101083032490977
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=700...
# done in 0.351s.
#
# Topics in LDA model:
# Topic #0: product food service computer water production waste market trade recycle dry produce agricultural tomato powder group ginger application advertising onion
# Topic #1: product production create market local service agricultural make farm farmer produce food social sustainable young rural fruit agriculture develop community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 700, 'doc_topic_prior': 0.1}
# precision 0.36101083032490977
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=800...
# done in 0.308s.
#
# Topics in LDA model:
# Topic #0: product create market production local agricultural service farm make produce farmer social sustainable food young rural agriculture fruit group develop
# Topic #1: product service food marketing production trade school oil fruit association crop private dry creation sugar juice smooth benefit hygiene communication
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 800, 'doc_topic_prior': 0.1}
# precision 98.73646209386283
# Extracting tf features for LDA...
# done in 0.019s.
#
# Fitting LDA models with tf features, n_features=900...
# done in 0.586s.
#
# Topics in LDA model:
# Topic #0: service product create local sustainable water technology market social rural energy access group organization develop maintenance monitor make brand farmer
# Topic #1: product production agricultural create market produce food local farm make farmer service young fruit agriculture waste social rural sustainable organic
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 900, 'doc_topic_prior': 0.1}
# precision 5.595667870036101
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=1000...
# done in 0.313s.
#
# Topics in LDA model:
# Topic #0: product make create young farm production agricultural egg meet community bean poultry produce order environmental industry seed trial import life
# Topic #1: product production create market service local agricultural food farmer produce farm make social sustainable fruit rural young agriculture group develop
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1000, 'doc_topic_prior': 0.1}
# precision 0.0
# Extracting tf features for LDA...
# done in 0.019s.
#
# Fitting LDA models with tf features, n_features=1100...
# done in 0.348s.
#
# Topics in LDA model:
# Topic #0: product production create market service agricultural local food produce make farmer farm young social rural fruit group agriculture sustainable community
# Topic #1: sustainable product farm farmer waste create economy local social city develop affordable responsible young make creation deliver school bean job
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1100, 'doc_topic_prior': 0.1}
# precision 99.45848375451264
# Extracting tf features for LDA...
# done in 0.020s.
#
# Fitting LDA models with tf features, n_features=1200...
# done in 0.542s.
#
# Topics in LDA model:
# Topic #0: product create make service production produce brand social local school information purchase community industry university trade young advertising economic market
# Topic #1: product market production agricultural local create farmer service farm food fruit sustainable produce agriculture young group rural social make organization
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1200, 'doc_topic_prior': 0.1}
# precision 1.444043321299639
# Extracting tf features for LDA...
# done in 0.021s.
#
# Fitting LDA models with tf features, n_features=1300...
# done in 0.349s.
#
# Topics in LDA model:
# Topic #0: product create production agricultural market local service food farmer produce farm make sustainable young fruit social agriculture group rural organization
# Topic #1: market production marketing service information product industry skill social community rural trade table shop local status brand affordable natural building
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1300, 'doc_topic_prior': 0.1}
# precision 99.09747292418773
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=1400...
# done in 0.346s.
#
# Topics in LDA model:
# Topic #0: product production create market service local agricultural food produce make farm farmer social fruit sustainable rural young agriculture group develop
# Topic #1: product sustainable young city creation school communication job restaurant marketing bean catering serve agrobusiness employ create affordable working dedicate tradition
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1400, 'doc_topic_prior': 0.1}
# precision 99.63898916967509
# Extracting tf features for LDA...
# done in 0.024s.
#
# Fitting LDA models with tf features, n_features=1500...
# done in 0.424s.
#
# Topics in LDA model:
# Topic #0: product production market service agricultural create local food produce farm farmer make fruit social agriculture rural young sustainable group water
# Topic #1: create product local sustainable young field make develop global purchase waste strategic child market farmer social live bean affordable economy
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1500, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.019s.
#
# Fitting LDA models with tf features, n_features=1600...
# done in 0.352s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1600, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.019s.
#
# Fitting LDA models with tf features, n_features=1700...
# done in 0.322s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1700, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.023s.
#
# Fitting LDA models with tf features, n_features=1800...
# done in 0.340s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1800, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.035s.
#
# Fitting LDA models with tf features, n_features=1900...
# done in 0.523s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1900, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.024s.
#
# Fitting LDA models with tf features, n_features=2000...
# done in 0.358s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2000, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=2100...
# done in 0.373s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2100, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.019s.
#
# Fitting LDA models with tf features, n_features=2200...
# done in 0.364s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2200, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=2300...
# done in 0.467s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2300, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.029s.
#
# Fitting LDA models with tf features, n_features=2400...
# done in 0.702s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2400, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=2500...
# done in 0.482s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2500, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=2600...
# done in 0.347s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2600, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.081s.
#
# Fitting LDA models with tf features, n_features=2700...
# done in 0.449s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2700, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=2800...
# done in 0.311s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2800, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=2900...
# done in 0.323s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2900, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3000...
# done in 0.314s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3000, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=3100...
# done in 0.358s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3100, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3200...
# done in 0.313s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3200, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3300...
# done in 0.321s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3300, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3400...
# done in 0.312s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3400, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3500...
# done in 0.319s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3500, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=3600...
# done in 0.314s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3600, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3700...
# done in 0.374s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3700, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3800...
# done in 0.322s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3800, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3900...
# done in 0.308s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3900, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=4000...
# done in 0.316s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4000, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4100...
# done in 0.310s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4100, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=4200...
# done in 0.316s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4200, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4300...
# done in 0.308s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4300, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4400...
# done in 0.322s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4400, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=4500...
# done in 0.313s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4500, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.019s.
#
# Fitting LDA models with tf features, n_features=4600...
# done in 0.328s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4600, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=4700...
# done in 0.307s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4700, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.020s.
#
# Fitting LDA models with tf features, n_features=4800...
# done in 0.320s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4800, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=4900...
# done in 0.308s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product paste seed oil waste plastic peanut recycle dedicate communication marketing end energy cover transforms chocolate produce renewable shell consumable
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4900, 'doc_topic_prior': 0.1}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=500...
# done in 0.445s.
#
# Topics in LDA model:
# Topic #0: service product water energy maintenance school technology rural sustainable make access cover oil renewable create power equipment trade digital sustainability
# Topic #1: product production create market local agricultural produce food farm farmer make social young fruit service group agriculture develop sustainable rural
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 500, 'doc_topic_prior': 0.2}
# precision 2.527075812274368
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=600...
# done in 0.369s.
#
# Topics in LDA model:
# Topic #0: create community rural local make market young social child information organization affordable access establish knowledge service maintenance sustainable technology strong
# Topic #1: product production market agricultural create service local food farm produce farmer make fruit sustainable group agriculture social young develop waste
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 600, 'doc_topic_prior': 0.2}
# precision 0.18050541516245489
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=700...
# done in 0.354s.
#
# Topics in LDA model:
# Topic #0: product service food water waste production market recycle trade dry powder computer application advertising pharmaceutical meal benefit kitchen basic law
# Topic #1: product production create market local service agricultural make produce farm farmer food social sustainable young fruit rural agriculture develop group
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 700, 'doc_topic_prior': 0.2}
# precision 0.36101083032490977
# Extracting tf features for LDA...
# done in 0.020s.
#
# Fitting LDA models with tf features, n_features=800...
# done in 0.413s.
#
# Topics in LDA model:
# Topic #0: product create market production local agricultural service farm make produce farmer social sustainable young food rural agriculture fruit group develop
# Topic #1: product service food marketing production trade school fruit oil juice sugar association crop creation private dry smooth transformation hygiene agribusiness
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 800, 'doc_topic_prior': 0.2}
# precision 98.55595667870037
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=900...
# done in 0.560s.
#
# Topics in LDA model:
# Topic #0: service product create local water sustainable technology market social energy access rural group organization maintenance monitor develop field make brand
# Topic #1: product production agricultural create market produce local food farm make farmer service young fruit agriculture social waste rural sustainable crop
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 900, 'doc_topic_prior': 0.2}
# precision 4.693140794223827
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=1000...
# done in 0.328s.
#
# Topics in LDA model:
# Topic #0: product make create young farm production agricultural egg community meet produce bean poultry environmental order industry seed import maize life
# Topic #1: product production create market service local agricultural food farmer produce farm make social sustainable fruit rural young agriculture group develop
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1000, 'doc_topic_prior': 0.2}
# precision 0.0
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=1100...
# done in 0.372s.
#
# Topics in LDA model:
# Topic #0: product production create market service local agricultural food make produce farmer farm young social rural fruit group agriculture sustainable community
# Topic #1: sustainable product farm farmer create waste social economy local city develop make affordable produce responsible market young financial creation deliver
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1100, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1200...
# done in 0.471s.
#
# Topics in LDA model:
# Topic #0: product create make production service produce brand information school public local social trade university advertising purchase young market industry community
# Topic #1: product market production create local agricultural farmer service farm food fruit sustainable agriculture produce young rural social group make organization
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1200, 'doc_topic_prior': 0.2}
# precision 1.083032490974729
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1300...
# done in 0.398s.
#
# Topics in LDA model:
# Topic #0: product create production agricultural market local service food farmer produce farm make sustainable young fruit social agriculture group rural develop
# Topic #1: market marketing production information service product trade industry social rural local community brand natural skill building knowledge make construction strategy
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1300, 'doc_topic_prior': 0.2}
# precision 99.09747292418773
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=1400...
# done in 0.325s.
#
# Topics in LDA model:
# Topic #0: product production create market service local agricultural food produce make farm farmer social fruit rural sustainable young agriculture group develop
# Topic #1: product sustainable young city creation communication school job restaurant create marketing bean catering serve employ tradition agrobusiness affordable dedicate working
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1400, 'doc_topic_prior': 0.2}
# precision 99.63898916967509
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=1500...
# done in 0.481s.
#
# Topics in LDA model:
# Topic #0: product production market service create agricultural local food produce make farm farmer fruit young social agriculture rural sustainable group community
# Topic #1: product create local sustainable communication develop purchase waste social farmer young field global strategic make bean affordable economy farm recycle
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1500, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1600...
# done in 0.356s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1600, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1700...
# done in 0.342s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1700, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1800...
# done in 0.360s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1800, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=1900...
# done in 0.343s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 1900, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=2000...
# done in 0.360s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2000, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=2100...
# done in 0.347s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2100, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=2200...
# done in 0.345s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2200, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2300...
# done in 0.359s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2300, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=2400...
# done in 0.369s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2400, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=2500...
# done in 0.355s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2500, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.020s.
#
# Fitting LDA models with tf features, n_features=2600...
# done in 0.483s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2600, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.027s.
#
# Fitting LDA models with tf features, n_features=2700...
# done in 0.518s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2700, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.021s.
#
# Fitting LDA models with tf features, n_features=2800...
# done in 0.490s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2800, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=2900...
# done in 0.403s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2900, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3000...
# done in 0.350s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3000, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.020s.
#
# Fitting LDA models with tf features, n_features=3100...
# done in 0.359s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3100, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=3200...
# done in 0.349s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3200, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=3300...
# done in 0.321s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3300, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3400...
# done in 0.342s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3400, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3500...
# done in 0.379s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3500, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.014s.
#
# Fitting LDA models with tf features, n_features=3600...
# done in 0.343s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3600, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3700...
# done in 0.385s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3700, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3800...
# done in 0.331s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3800, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3900...
# done in 0.355s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3900, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.021s.
#
# Fitting LDA models with tf features, n_features=4000...
# done in 0.344s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# Topic #1: product seed paste oil waste plastic peanut recycle communication dedicate energy end marketing cover transforms renewable chocolate produce service shell
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4000, 'doc_topic_prior': 0.2}
# precision 99.27797833935018
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=4100...
# done in 0.345s.
#
# Topics in LDA model:
# Topic #0: product production create market local service agricultural food farmer make farm produce social young sustainable fruit rural agriculture group develop
# ...
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2500, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=2600...
# done in 0.260s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2600, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.022s.
#
# Fitting LDA models with tf features, n_features=2700...
# done in 0.319s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2700, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=2800...
# done in 0.310s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2800, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=2900...
# done in 0.241s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 2900, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.015s.
#
# Fitting LDA models with tf features, n_features=3000...
# done in 0.245s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3000, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.045s.
#
# Fitting LDA models with tf features, n_features=3100...
# done in 0.578s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3100, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.018s.
#
# Fitting LDA models with tf features, n_features=3200...
# done in 0.439s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3200, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=3300...
# done in 0.333s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3300, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=3400...
# done in 0.301s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3400, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.016s.
#
# Fitting LDA models with tf features, n_features=3500...
# done in 0.305s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3500, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.017s.
#
# Fitting LDA models with tf features, n_features=3600...
# done in 0.321s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3600, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.045s.
#
# Fitting LDA models with tf features, n_features=3700...
# done in 0.712s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3700, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.035s.
#
# Fitting LDA models with tf features, n_features=3800...
# done in 0.578s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3800, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.031s.
#
# Fitting LDA models with tf features, n_features=3900...
# done in 0.537s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 3900, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.021s.
#
# Fitting LDA models with tf features, n_features=4000...
# done in 0.458s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4000, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.037s.
#
# Fitting LDA models with tf features, n_features=4100...
# done in 0.499s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4100, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.023s.
#
# Fitting LDA models with tf features, n_features=4200...
# done in 0.465s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4200, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.026s.
#
# Fitting LDA models with tf features, n_features=4300...
# done in 0.467s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4300, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.024s.
#
# Fitting LDA models with tf features, n_features=4400...
# done in 0.412s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4400, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.025s.
#
# Fitting LDA models with tf features, n_features=4500...
# done in 0.486s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4500, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.024s.
#
# Fitting LDA models with tf features, n_features=4600...
# done in 0.395s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4600, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.024s.
#
# Fitting LDA models with tf features, n_features=4700...
# done in 0.392s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4700, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.024s.
#
# Fitting LDA models with tf features, n_features=4800...
# done in 0.493s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4800, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
# Extracting tf features for LDA...
# done in 0.023s.
#
# Fitting LDA models with tf features, n_features=4900...
# done in 0.418s.
#
# Topics in LDA model:
# Topic #0: product production create agricultural local food market farmer social service young make management farm sustainable produce fruit organization develop marketing
# Topic #1: product market service production create local produce farm make rural agricultural sustainable agriculture fruit group food farmer young woman community
#
# {'n_components': 2, 'n_top_words': 20, 'n_features': 4900, 'doc_topic_prior': 9.9}
# precision 66.06498194945848
#      n_components  n_top_words  n_features  doc_topic_prior  precision  \
# 144             2           20        1400              0.4  99.638989
# 54              2           20        1400              0.2  99.638989
# 99              2           20        1400              0.3  99.638989
# 9               2           20        1400              0.1  99.638989
# 189             2           20        1400              0.5  99.638989
# ..            ...          ...         ...              ...        ...
# 46              2           20         600              0.2   0.180505
# 50              2           20        1000              0.2   0.000000
# 95              2           20        1000              0.3   0.000000
# 5               2           20        1000              0.1   0.000000
# 140             2           20        1000              0.4   0.000000
#
#                                            vocabulaire
# 144  [abandon, ability, abroad, absorb, access, acc...
# 54   [abandon, ability, abroad, absorb, access, acc...
# 99   [abandon, ability, abroad, absorb, access, acc...
# 9    [abandon, ability, abroad, absorb, access, acc...
# 189  [abandon, ability, abroad, absorb, access, acc...
# ..                                                 ...
# 46   [access, accessible, accompany, account, acqui...
# 50   [abandon, ability, access, accessible, accompa...
# 95   [abandon, ability, access, accessible, accompa...
# 5    [abandon, ability, access, accessible, accompa...
# 140  [abandon, ability, access, accessible, accompa...
#
# [4455 rows x 6 columns]

# %%
results.sort_values('precision', ascending = False)
# Out:
#      n_components  n_top_words  n_features  doc_topic_prior  precision  \
# 144             2           20        1400              0.4  99.638989
# 54              2           20        1400              0.2  99.638989
# 99              2           20        1400              0.3  99.638989
# 9               2           20        1400              0.1  99.638989
# 189             2           20        1400              0.5  99.638989
# ..            ...          ...         ...              ...        ...
# 46              2           20         600              0.2   0.180505
# 50              2           20        1000              0.2   0.000000
# 95              2           20        1000              0.3   0.000000
# 5               2           20        1000              0.1   0.000000
# 140             2           20        1000              0.4   0.000000
#
#                                            vocabulaire
# 144  [abandon, ability, abroad, absorb, access, acc...
# 54   [abandon, ability, abroad, absorb, access, acc...
# 99   [abandon, ability, abroad, absorb, access, acc...
# 9    [abandon, ability, abroad, absorb, access, acc...
# 189  [abandon, ability, abroad, absorb, access, acc...
# ..                                                 ...
# 46   [access, accessible, accompany, account, acqui...
# 50   [abandon, ability, access, accessible, accompa...
# 95   [abandon, ability, access, accessible, accompa...
# 5    [abandon, ability, access, accessible, accompa...
# 140  [abandon, ability, access, accessible, accompa...
#
# [4455 rows x 6 columns]

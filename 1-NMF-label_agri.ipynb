# %%
import chalenge1000
import model_lib
import collections
from IPython.display import display, HTML

# %%
def vocab(element):
    if type(element) == str:
        return ' '.join(set(element.split(' ')))
    else:
        return ''

col_count = lambda x: ' '.join([a for a,b in collections.Counter(x.split()).most_common(10000)])
lemm = lambda x: model_lib.Lemm(x,file = 'stopwords_agri.txt').X


Chalenge = chalenge1000.Native()

df = Chalenge.X
df['corpus'] = df.join(Chalenge.descriptions_trad)[['prez_struc','prez_produit_struc']].agg(sum, axis = 1)
df['type'] = df['corpus'].map(type)
df['corpus'] = df['corpus'].map(vocab)
df['corpus_lemm'] = df['corpus'].map(lemm)
df['collection_counter'] = df['corpus_lemm'].map(col_count)
df = df[df['type'] ==str]

# %%
agriculture = df[df['categorie'] == 'agriculture']
others = df[df['categorie'].isin([ 'media'])]

corpus_agri = agriculture['collection_counter'].agg(sum, axis = 0)
#corpus_agri = model_lib.Lemm(corpus_agri,file = 'stopwords_agri.txt').X
corpus_others = others['collection_counter'].agg(sum, axis = 0)
#corpus_others = model_lib.Lemm(corpus_others,file = 'stopwords_agri.txt').X

counter_agri = collections.Counter(corpus_agri.split()).most_common(5000)
counter_others = collections.Counter(corpus_others.split()).most_common(5000)

counter_agri = list({(a,b) for a,b in counter_agri}.union({(k,0) for k,l in counter_others if k not in [a for a,b in counter_agri]}))
counter_others = list({(a,b) for a,b in counter_others}.union({(k,0) for k,l in counter_agri if k not in [a for a,b in counter_others]}))
counter_agri = {(a, b*100/len(agriculture)) for a,b in counter_agri}
counter_others = {(a, b*100/len(others)) for a,b in counter_others}

import operator

id = operator.itemgetter(0)  # To get id field.

idinfo = {id(rec): rec[1:] for rec in counter_agri}  # Dict for fast look-ups.

merged = [info + idinfo[id(info)] for info in counter_others if id(info) in idinfo]

merged.sort(key=lambda x: x[2], reverse = True)

map_vocab = [(a,c,b, c-b) for a,b,c in merged]
map_vocab.sort(key=lambda x: x[-1], reverse = True)

import pandas

keyword_map = pandas.DataFrame(map_vocab, columns = ['keyword','agriculture', 'others', 'difference']).sort_values('difference')

keyword_map.describe(include= 'all')

keyword_map.sort_values('difference', ascending = False)
# Out:
#             keyword  agriculture     others  difference
# 0      agricultural    35.827338   2.173913   33.653425
# 1              food    37.697842   4.347826   33.350016
# 2              farm    29.496403   0.000000   29.496403
# 3            farmer    29.352518   1.086957   28.265561
# 4       agriculture    25.899281   2.173913   23.725368
# ...             ...          ...        ...         ...
# 6202          event     1.726619  19.565217  -17.838599
# 6203        graphic     0.000000  18.478261  -18.478261
# 6204         agency     2.589928  25.000000  -22.410072
# 6205  communication     4.316547  30.434783  -26.118236
# 6206        digital     7.769784  40.217391  -32.447607
#
# [6207 rows x 4 columns]

# %%
keyword_map.sort_values('difference', ascending = False)
# Out:
#             keyword  agriculture     others  difference
# 0      agricultural    35.827338   2.173913   33.653425
# 1              food    37.697842   4.347826   33.350016
# 2              farm    29.496403   0.000000   29.496403
# 3            farmer    29.352518   1.086957   28.265561
# 4       agriculture    25.899281   2.173913   23.725368
# ...             ...          ...        ...         ...
# 6202          event     1.726619  19.565217  -17.838599
# 6203        graphic     0.000000  18.478261  -18.478261
# 6204         agency     2.589928  25.000000  -22.410072
# 6205  communication     4.316547  30.434783  -26.118236
# 6206        digital     7.769784  40.217391  -32.447607
#
# [6207 rows x 4 columns]

# %%
subset_1 = keyword_map[(keyword_map['difference'] > 15) |  (keyword_map['difference'] < -15) ]#|  (keyword_map['agriculture'] > 15)]

subset_1.sort_values('difference', ascending = False)
# Out:
#             keyword  agriculture     others  difference
# 0      agricultural    35.827338   2.173913   33.653425
# 1              food    37.697842   4.347826   33.350016
# 2              farm    29.496403   0.000000   29.496403
# 3            farmer    29.352518   1.086957   28.265561
# 4       agriculture    25.899281   2.173913   23.725368
# 5           produce    36.115108  13.043478   23.071630
# 6           product    53.381295  31.521739   21.859556
# 7        production    41.151079  21.739130   19.411949
# 8         vegetable    18.417266   0.000000   18.417266
# 9             rural    21.582734   3.260870   18.321864
# 10             crop    17.553957   0.000000   17.553957
# 11          organic    19.712230   2.173913   17.538317
# 12            plant    17.410072   0.000000   17.410072
# 13          natural    17.122302   1.086957   16.035346
# 6196        content     3.453237  18.478261  -15.025023
# 6197          video     0.863309  16.304348  -15.441038
# 6198         public     6.043165  21.739130  -15.695965
# 6199    information     8.201439  23.913043  -15.711605
# 6200       platform    12.230216  29.347826  -17.117610
# 6201        service    23.884892  41.304348  -17.419456
# 6202          event     1.726619  19.565217  -17.838599
# 6203        graphic     0.000000  18.478261  -18.478261
# 6204         agency     2.589928  25.000000  -22.410072
# 6205  communication     4.316547  30.434783  -26.118236
# 6206        digital     7.769784  40.217391  -32.447607

# %%
subset_1 = keyword_map[(keyword_map['difference'] > 15) |  (keyword_map['difference'] < -15) |  (keyword_map['agriculture'] > 15)]

subset_1.sort_values('difference', ascending = False)
# Out:
#             keyword  agriculture     others  difference
# 0      agricultural    35.827338   2.173913   33.653425
# 1              food    37.697842   4.347826   33.350016
# 2              farm    29.496403   0.000000   29.496403
# 3            farmer    29.352518   1.086957   28.265561
# 4       agriculture    25.899281   2.173913   23.725368
# 5           produce    36.115108  13.043478   23.071630
# 6           product    53.381295  31.521739   21.859556
# 7        production    41.151079  21.739130   19.411949
# 8         vegetable    18.417266   0.000000   18.417266
# 9             rural    21.582734   3.260870   18.321864
# 10             crop    17.553957   0.000000   17.553957
# 11          organic    19.712230   2.173913   17.538317
# 12            plant    17.410072   0.000000   17.410072
# 13          natural    17.122302   1.086957   16.035346
# 15      sustainable    21.870504   7.608696   14.261808
# 16           market    40.287770  26.086957   14.200813
# 18            woman    16.834532   4.347826   12.486706
# 19           system    17.266187   5.434783   11.831404
# 23            local    29.640288  19.565217   10.075070
# 37             make    37.841727  29.347826    8.493901
# 53           access    15.395683   8.695652    6.700031
# 73            order    20.719424  15.217391    5.502033
# 84              one    18.129496  13.043478    5.086018
# 90              two    15.827338  10.869565    4.957773
# 163            also    40.287770  36.956522    3.331248
# 387         develop    19.136691  17.391304    1.745386
# 740      technology    16.258993  15.217391    1.041602
# 1229           well    20.143885  19.565217    0.578668
# 4085         create    33.381295  33.695652   -0.314357
# 4517     management    19.712230  20.652174   -0.939944
# 5687          field    15.107914  16.304348   -1.196434
# 6158         social    17.410072  23.913043   -6.502972
# 6174          young    18.705036  27.173913   -8.468877
# 6196        content     3.453237  18.478261  -15.025023
# 6197          video     0.863309  16.304348  -15.441038
# 6198         public     6.043165  21.739130  -15.695965
# 6199    information     8.201439  23.913043  -15.711605
# 6200       platform    12.230216  29.347826  -17.117610
# 6201        service    23.884892  41.304348  -17.419456
# 6202          event     1.726619  19.565217  -17.838599
# 6203        graphic     0.000000  18.478261  -18.478261
# 6204         agency     2.589928  25.000000  -22.410072
# 6205  communication     4.316547  30.434783  -26.118236
# 6206        digital     7.769784  40.217391  -32.447607

# %%
import numpy
percentile = lambda x: numpy.percentile(x,[50, 66, 90,95,99])
print(percentile(keyword_map[keyword_map['agriculture'] > 0]['agriculture'].values.tolist()))
print(percentile(keyword_map[keyword_map['difference'] > 0]['agriculture'].values.tolist()))
print(percentile(keyword_map[keyword_map['difference'] < 0]['agriculture'].values.tolist()))

numpy.mean(keyword_map[keyword_map['agriculture'] > 0]['agriculture'].values.tolist())
# Out:
# [ 0.43165468  0.71942446  2.73381295  4.89208633 12.23021583]
# [ 0.43165468  0.71942446  2.58992806  4.60431655 11.85467626]
# [0.         0.43165468 1.72661871 3.16546763 8.9381295 ]
# 1.276978417266187

# %% [markdown]
# # Entrainement
# ## NMF

# %%
def get_topic(e):
    if e >0:
        return 'agriculture'
    if e<0:
        return 'media'
    
def true_positve(a,b):
    if a == b:
        return 1
    else:
        return 0
    
    
n_components = 2
n_top_words = 20
n_features = 20000
text_corpus = df[df['categorie'].isin(['agriculture','media'])]['collection_counter']
model = model_lib.Models(n_components = n_components, n_top_words =n_top_words, n_features = n_features)
models = model.run_model_NMF(text_corpus.values.tolist())

predict = pandas.DataFrame(model.reverse_nmf(text_corpus.values.tolist(), models) , index =text_corpus.index)
display(predict)

predict = predict.join(df['categorie'])
predict[0] = predict[0]*100
predict[1] = predict[1]*100
predict['topic'] = predict[0]-predict[1]
display(predict)

predict['predict_label'] = predict['topic'].map(get_topic)
display(predict)

predict['classification_kpi'] = predict.apply(lambda x: true_positve(x['categorie'],x['predict_label']), axis= 1)
display(predict)
# Out:
# done in 0.000s.
# Extracting tf-idf features for NMF...
# done in 0.131s.
# Fitting the NMF model (Frobenius norm) with tf-idf features, n_samples=2000 and n_features=20000...
# done in 0.051s.
# Topic #0: product agricultural production market produce food farmer farm make create agriculture local service organic rural sustainable vegetable order develop train
# Topic #1: digital communication agency advertising graphic event service design web information platform video strategy public tv marketing creation magazine management social
#                                                            0         1
# key_main
# http://chapwifi.bj/_adjassa_azimath                 0.025331  0.115039
# https://www.facebook.com/TZenSn/_diop_sokhnalaye    0.039032  0.000000
# http://www.sunumbay-agritech.sn/_aw_mohamedelbe...  0.090820  0.035286
# http://www.Gh+entreprise.con_ngombesekou_godely...  0.058873  0.000000
# http://www.retpaci.ci_kouassi_ayagazalo             0.076488  0.000000
# ...                                                      ...       ...
# http://www.cbdibaong.org_houedanou_martin           0.062789  0.000000
# http://www.cbdibaong.org_yemadje_emeline            0.035569  0.000000
# http://www.cbdibaong.org_akokponsode_hippolyte      0.053565  0.000000
# http://www.cbdibaong.org_aholou_pulcherie           0.058902  0.000000
# http://www.cbdibaong.org_tchegninougbo_marcelline   0.062620  0.000000
#
# [787 rows x 2 columns]
#                                                            0          1  \
# key_main
# http://chapwifi.bj/_adjassa_azimath                 2.533099  11.503889
# https://www.facebook.com/TZenSn/_diop_sokhnalaye    3.903166   0.000000
# http://www.sunumbay-agritech.sn/_aw_mohamedelbe...  9.082026   3.528554
# http://www.Gh+entreprise.con_ngombesekou_godely...  5.887270   0.000000
# http://www.retpaci.ci_kouassi_ayagazalo             7.648795   0.000000
# ...                                                      ...        ...
# http://www.cbdibaong.org_houedanou_martin           6.278871   0.000000
# http://www.cbdibaong.org_yemadje_emeline            3.556936   0.000000
# http://www.cbdibaong.org_akokponsode_hippolyte      5.356473   0.000000
# http://www.cbdibaong.org_aholou_pulcherie           5.890204   0.000000
# http://www.cbdibaong.org_tchegninougbo_marcelline   6.261972   0.000000
#
#                                                       categorie     topic
# key_main
# http://chapwifi.bj/_adjassa_azimath                       media -8.970790
# https://www.facebook.com/TZenSn/_diop_sokhnalaye    agriculture  3.903166
# http://www.sunumbay-agritech.sn/_aw_mohamedelbe...  agriculture  5.553472
# http://www.Gh+entreprise.con_ngombesekou_godely...  agriculture  5.887270
# http://www.retpaci.ci_kouassi_ayagazalo             agriculture  7.648795
# ...                                                         ...       ...
# http://www.cbdibaong.org_houedanou_martin           agriculture  6.278871
# http://www.cbdibaong.org_yemadje_emeline            agriculture  3.556936
# http://www.cbdibaong.org_akokponsode_hippolyte      agriculture  5.356473
# http://www.cbdibaong.org_aholou_pulcherie           agriculture  5.890204
# http://www.cbdibaong.org_tchegninougbo_marcelline   agriculture  6.261972
#
# [787 rows x 4 columns]
#                                                            0          1  \
# key_main
# http://chapwifi.bj/_adjassa_azimath                 2.533099  11.503889
# https://www.facebook.com/TZenSn/_diop_sokhnalaye    3.903166   0.000000
# http://www.sunumbay-agritech.sn/_aw_mohamedelbe...  9.082026   3.528554
# http://www.Gh+entreprise.con_ngombesekou_godely...  5.887270   0.000000
# http://www.retpaci.ci_kouassi_ayagazalo             7.648795   0.000000
# ...                                                      ...        ...
# http://www.cbdibaong.org_houedanou_martin           6.278871   0.000000
# http://www.cbdibaong.org_yemadje_emeline            3.556936   0.000000
# http://www.cbdibaong.org_akokponsode_hippolyte      5.356473   0.000000
# http://www.cbdibaong.org_aholou_pulcherie           5.890204   0.000000
# http://www.cbdibaong.org_tchegninougbo_marcelline   6.261972   0.000000
#
#                                                       categorie     topic  \
# key_main
# http://chapwifi.bj/_adjassa_azimath                       media -8.970790
# https://www.facebook.com/TZenSn/_diop_sokhnalaye    agriculture  3.903166
# http://www.sunumbay-agritech.sn/_aw_mohamedelbe...  agriculture  5.553472
# http://www.Gh+entreprise.con_ngombesekou_godely...  agriculture  5.887270
# http://www.retpaci.ci_kouassi_ayagazalo             agriculture  7.648795
# ...                                                         ...       ...
# http://www.cbdibaong.org_houedanou_martin           agriculture  6.278871
# http://www.cbdibaong.org_yemadje_emeline            agriculture  3.556936
# http://www.cbdibaong.org_akokponsode_hippolyte      agriculture  5.356473
# http://www.cbdibaong.org_aholou_pulcherie           agriculture  5.890204
# http://www.cbdibaong.org_tchegninougbo_marcelline   agriculture  6.261972
#
#                                                    predict_label
# key_main
# http://chapwifi.bj/_adjassa_azimath                        media
# https://www.facebook.com/TZenSn/_diop_sokhnalaye     agriculture
# http://www.sunumbay-agritech.sn/_aw_mohamedelbe...   agriculture
# http://www.Gh+entreprise.con_ngombesekou_godely...   agriculture
# http://www.retpaci.ci_kouassi_ayagazalo              agriculture
# ...                                                          ...
# http://www.cbdibaong.org_houedanou_martin            agriculture
# http://www.cbdibaong.org_yemadje_emeline             agriculture
# http://www.cbdibaong.org_akokponsode_hippolyte       agriculture
# http://www.cbdibaong.org_aholou_pulcherie            agriculture
# http://www.cbdibaong.org_tchegninougbo_marcelline    agriculture
#
# [787 rows x 5 columns]
#                                                            0          1  \
# key_main
# http://chapwifi.bj/_adjassa_azimath                 2.533099  11.503889
# https://www.facebook.com/TZenSn/_diop_sokhnalaye    3.903166   0.000000
# http://www.sunumbay-agritech.sn/_aw_mohamedelbe...  9.082026   3.528554
# http://www.Gh+entreprise.con_ngombesekou_godely...  5.887270   0.000000
# http://www.retpaci.ci_kouassi_ayagazalo             7.648795   0.000000
# ...                                                      ...        ...
# http://www.cbdibaong.org_houedanou_martin           6.278871   0.000000
# http://www.cbdibaong.org_yemadje_emeline            3.556936   0.000000
# http://www.cbdibaong.org_akokponsode_hippolyte      5.356473   0.000000
# http://www.cbdibaong.org_aholou_pulcherie           5.890204   0.000000
# http://www.cbdibaong.org_tchegninougbo_marcelline   6.261972   0.000000
#
#                                                       categorie     topic  \
# key_main
# http://chapwifi.bj/_adjassa_azimath                       media -8.970790
# https://www.facebook.com/TZenSn/_diop_sokhnalaye    agriculture  3.903166
# http://www.sunumbay-agritech.sn/_aw_mohamedelbe...  agriculture  5.553472
# http://www.Gh+entreprise.con_ngombesekou_godely...  agriculture  5.887270
# http://www.retpaci.ci_kouassi_ayagazalo             agriculture  7.648795
# ...                                                         ...       ...
# http://www.cbdibaong.org_houedanou_martin           agriculture  6.278871
# http://www.cbdibaong.org_yemadje_emeline            agriculture  3.556936
# http://www.cbdibaong.org_akokponsode_hippolyte      agriculture  5.356473
# http://www.cbdibaong.org_aholou_pulcherie           agriculture  5.890204
# http://www.cbdibaong.org_tchegninougbo_marcelline   agriculture  6.261972
#
#                                                    predict_label  \
# key_main
# http://chapwifi.bj/_adjassa_azimath                        media
# https://www.facebook.com/TZenSn/_diop_sokhnalaye     agriculture
# http://www.sunumbay-agritech.sn/_aw_mohamedelbe...   agriculture
# http://www.Gh+entreprise.con_ngombesekou_godely...   agriculture
# http://www.retpaci.ci_kouassi_ayagazalo              agriculture
# ...                                                          ...
# http://www.cbdibaong.org_houedanou_martin            agriculture
# http://www.cbdibaong.org_yemadje_emeline             agriculture
# http://www.cbdibaong.org_akokponsode_hippolyte       agriculture
# http://www.cbdibaong.org_aholou_pulcherie            agriculture
# http://www.cbdibaong.org_tchegninougbo_marcelline    agriculture
#
#                                                     classification_kpi
# key_main
# http://chapwifi.bj/_adjassa_azimath                                  1
# https://www.facebook.com/TZenSn/_diop_sokhnalaye                     1
# http://www.sunumbay-agritech.sn/_aw_mohamedelbe...                   1
# http://www.Gh+entreprise.con_ngombesekou_godely...                   1
# http://www.retpaci.ci_kouassi_ayagazalo                              1
# ...                                                                ...
# http://www.cbdibaong.org_houedanou_martin                            1
# http://www.cbdibaong.org_yemadje_emeline                             1
# http://www.cbdibaong.org_akokponsode_hippolyte                       1
# http://www.cbdibaong.org_aholou_pulcherie                            1
# http://www.cbdibaong.org_tchegninougbo_marcelline                    1
#
# [787 rows x 6 columns]

# %% [raw]
# Topic #0:
# product agricultural production market food produce farmer farm create make agriculture local service organic rural sustainable vegetable train develop order
#
# Topic #1:
# digital communication agency graphic service event design advertise information video web platform public tv strategy creation print social magazine management

# %%
agri = predict[predict['categorie'] =='agriculture']
print('precision {}'.format(agri['classification_kpi'].sum()/695*100))

errors = agri[agri['classification_kpi'] == 0].sort_values('topic')

collections.Counter(' '.join(errors.join(text_corpus)['collection_counter'].values.tolist()).split()).most_common(10)
# Out:
# precision 98.1294964028777
# [('communication', 6),
#  ('agricultural', 4),
#  ('market', 4),
#  ('product', 4),
#  ('digital', 4),
#  ('platform', 4),
#  ('service', 4),
#  ('consult', 3),
#  ('local', 3),
#  ('adapt', 3)]

# %%
template = errors.join(chalenge1000.Native().text['temp'])['temp'].values.tolist()
with open('misclassified_agri.txt', 'w') as file:
    for line in template:
        file.writelines(line)

# %% [markdown]
# # catégorie abscente

# %% [raw]
# ### catégorie autre structure
#
# industrie agroalimentaire
# agro industrie
# alimentations, distribution et services
# agroalimentaire - nutrition
# transformation  agro-alimentaire
# agroalimentaire (pâtisseries sans gluten à base des tubercules et céréales)
# agriculture en zone urbaine
# ecologie environnement changement climatique conjoint à l'agriculture hors sol
# artisanat, cosmétique, agro-transformation et nouvelle technologie(digital)
# aquaculture, pisciculture urbaine, sauvegarde de la biodiversité et sécurité alimentaire.
# financement de la production et la transformation agricole, financement des jeunes urbain pour des initiatives économiques
# agroalimentaire
# industrie agro alimentaire
# transformation alimentaire  ( produits à base d'insectes)
# transformation agroalimentaire

# %%
label = pandas.read_csv('datastore.csv').set_index('key_main')
label['corpus'] = label[label['_agriculture_']][['prez_struc','prez_produit_struc']].agg(sum, axis = 1)
label['type'] = label['corpus'].map(type)
label['corpus'] = label['corpus'].map(vocab)
label['corpus_lemm'] = label['corpus'].map(lemm)
label['collection_counter'] = label['corpus_lemm'].map(col_count)
label = label[label['type'] ==str]

n_components = 2
n_top_words = 20
n_features = 20000
text_corpus = label['collection_counter']

predict = pandas.DataFrame(model.reverse_nmf(text_corpus.values.tolist(), models) , index =text_corpus.index)
predict = predict.join(df['categorie'])
predict[0] = predict[0]*100
predict[1] = predict[1]*100
predict['topic'] = predict[0]-predict[1]
predict['predict_label'] = predict['topic'].map(get_topic)
predict['classification_kpi'] = predict.apply(lambda x: true_positve(x['categorie'],x['predict_label']), axis= 1)
predict.sort_values(0, ascending = False)[[0,1,'predict_label','topic']]
# Out:
#                                                            0         1  \
# key_main
# http://www.aquareignindustry.com_mbouleediango_...  6.607159  0.000000
# https://web.facebook.com/faycal.aguemon_aguemon...  5.565335  0.000000
# https://www.2mi-sa.com/_djermakoye_reki             3.547847  0.000000
# http://www.congofresh.com_enge_albert               3.477652  0.000000
# https://www.youtube.com/results?search_query=gu...  2.957206  0.000000
# http://www.leader-manioc-96.websel.net/site%20m...  2.863441  0.000000
# https://4piment.blogspot.com/_sinare_idrissa        2.133455  0.000000
# http://YamAgroIndustrie.bf_yameogo_stevearmandl...  1.945061  0.000000
# https://www.le-lionceau.com/_samba_siny             1.861991  6.776858
# http://www.madeintogo.com_wattara_fankjah           1.771159  0.443239
# https://www.trebalt.com/_bah_anais                  1.728305  5.099032
# https://web.facebook.com/davenbakery_ongmessom_...  1.679350  0.514246
# http://www.senebusiness.com_sene_ablaye             0.673157  0.000000
# https://www.petitepirogue.com_matembe_herve         0.349186  0.000000
# http://www.kobo-hub.com_latere_atiyasidonie         0.000000  0.000000
#
#                                                    predict_label     topic
# key_main
# http://www.aquareignindustry.com_mbouleediango_...   agriculture  6.607159
# https://web.facebook.com/faycal.aguemon_aguemon...   agriculture  5.565335
# https://www.2mi-sa.com/_djermakoye_reki              agriculture  3.547847
# http://www.congofresh.com_enge_albert                agriculture  3.477652
# https://www.youtube.com/results?search_query=gu...   agriculture  2.957206
# http://www.leader-manioc-96.websel.net/site%20m...   agriculture  2.863441
# https://4piment.blogspot.com/_sinare_idrissa         agriculture  2.133455
# http://YamAgroIndustrie.bf_yameogo_stevearmandl...   agriculture  1.945061
# https://www.le-lionceau.com/_samba_siny                    media -4.914867
# http://www.madeintogo.com_wattara_fankjah            agriculture  1.327920
# https://www.trebalt.com/_bah_anais                         media -3.370728
# https://web.facebook.com/davenbakery_ongmessom_...   agriculture  1.165104
# http://www.senebusiness.com_sene_ablaye              agriculture  0.673157
# https://www.petitepirogue.com_matembe_herve          agriculture  0.349186
# http://www.kobo-hub.com_latere_atiyasidonie                 None  0.000000

# %%
for e in predict[predict['predict_label'] == 'agriculture'].join(Chalenge.descriptions_trad)[['prez_struc','prez_produit_struc']].values.tolist()[0]:
    print(e)
# Out:
# Company specialized in the food processing made in Burkina Faso, we offer to the Burkinabe consumers syrup, biscuits and jam.
# We have two types of syrup, bissap and ginger. One is the chocolate cookies and one is mango jam. We plan to launch three new syrups and one jam on the market by March 2020.

# %% [markdown]
# # Startup non inscrits en agriculture

# %%
df = Chalenge.X
df['corpus'] = df.join(Chalenge.descriptions_trad)[['prez_struc','prez_produit_struc']].agg(sum, axis = 1)
df['type'] = df['corpus'].map(type)
df['corpus'] = df['corpus'].map(vocab)
df['corpus_lemm'] = df['corpus'].map(lemm)
df['collection_counter'] = df['corpus_lemm'].map(col_count)
df = df[df['type'] ==str]

n_components = 2
n_top_words = 20
n_features = 20000
text_corpus = df[df['categorie']!= 'agriculture']['collection_counter']

predict = pandas.DataFrame(model.reverse_nmf(text_corpus.values.tolist(), models) , index =text_corpus.index)
predict = predict.join(df['categorie'])
predict[0] = predict[0]*100
predict[1] = predict[1]*100
predict['topic'] = predict[0]-predict[1]
predict['predict_label'] = predict['topic'].map(get_topic)
predict['classification_kpi'] = predict.apply(lambda x: true_positve(x['categorie'],x['predict_label']), axis= 1)
#predict.sort_values(0, ascending = False)[[0,1,'predict_label']]

# %%
#predict.sort_values(0, ascending = False).describe()

# %%
#predict[predict['topic'] > 10].sort_values(0, ascending = False).groupby(['categorie','predict_label']).nunique()#.describe(include ='all')

# %%
predict[predict['topic']>10].join(chalenge1000.Native().text['temp'])[['categorie','predict_label']]
# Out:
#                                                        categorie predict_label
# key_main
# http://www.sukuchai.com_kuchengo_suleiman                 autres   agriculture
# https://www.facebook.com/Community-Action-for-A...     education   agriculture
# http://www.cleanprogb.com%20en%20contruction_et...       finance   agriculture
# https://afrikapu.com/_mohamed_nasreenali               ecommerce   agriculture
# https://www.facebook.com/TESSA-POWER-SARL-15401...       energie   agriculture
# ...                                                          ...           ...
# https://solarkoodo.com/_nana_safiatou                    energie   agriculture
# http://www.agrolimgroceriesuganda.com/_denis_mu...     ecommerce   agriculture
# http://www.afrimart.com.ng/_ojeniyi_olajide            ecommerce   agriculture
# http://www.me.bf/newkieta_zabsonre_abdoulaziz           mobilite   agriculture
# https://tenewagoal7.wordpress.com/_omossomoamas...  gouvernement   agriculture
#
# [89 rows x 2 columns]

# %%
a = predict[predict['topic']>10].join(chalenge1000.Native().text['temp'])['temp'].values.tolist()
print(a[0])
# Out:
# Nom du répondant : Kuchengo
# Prénom du répondant : Suleiman
# email : suleykuchengo@yahoo.com
#
# Nom de la structure : SUKU CHAI
# Pays d'origine : Tanzania
# Pays d'activité : Tanzania
# Site internet : http://www.sukuchai.com
# Linkedin : https://www.linkedin.com/in/suleiman-kuchengo-05a370123/?originalSubdomain=tz
#
# Présentation de la structure
# Our main goal is to improve lives in remote, impoverished and neglected rural areas by creating improved access to productive resources as well as meaningful jobs to single mothers, widows, people with disabilities and young girls through tea farming and value addition.
# Our approach is based on building an inclusive economy as we are challenging and disrupting the status quo by changing the way marginalized groups and excluded communities were left in the stake of the economy by giving them the necessary skills, tools, and resources to own the economy.
# What we do is to empower those marginalized and neglected groups through training and incentives, they are trained on how to grow and nurture tea and spices. After successful training, they are given seeds to start their own farms while supervised by our network of experts to ensure quality production.
# Then we buy all harvested products and process them into tea, this is to say Suku Chai sources, blends, flavors and packs creative teas with no additives and use only freshly ground spices which are dried and grounded for us as we guarantee our product retains its natural freshness and each cup captures the delightful taste of Tanzanian tea.
# Through this process, we have directly created 50 jobs to women especially single mothers, widows and young girls in Muheza and Kihesa Tanzania who are currently running small to medium size agribusiness.
# By 2025 we target to reach over 15, 000 rural communities in Tanga and Morogoro Tanzania by creating jobs and giving them skills and resources through tea farming and value addition.
#  SUKU CHAI aims to increase local tea value addition to economically empower marginalized groups and excluded communities, we ensures that people with disability and women especially single mothers, widows and young girls in rural areas are economically empowered while creating meaningful jobs for them and help their families as well as contributing to economic growth of the Country.
#
# Présentation du produit, de la solution phare porté par la structure
# Our tea products are 100% organic made from the finest Tanzanian tea infusing with ginger and lemongrass and other spices.
# We blend, pack and distribute the highest quality organic tea products of Tanzanian Origin free from caffeine and additional of any harmful chemicals better for improving blood glucose levels and fighting allergy.
# This is to say SUKU CHAI sources, blends, flavors, and packages creative teas with no additives and use only freshly ground spices that are dried and ground for us as we guarantee our product retains its natural freshness and each cup captures the delightful taste of Tanzanian tea.
#
# Sur quel marché et vers quelle cible
# Tanzania has over 55 Million populations, according to Tanzania Tea Board, the country produces more than 40,000 tons annually whereby about 75% of the production is exported and tea has become the third-largest foreign exchange generator accounting for more than $55 million to the country’s export earnings.
# It is also estimated that more than 37 million Tanzanians do consume tea, and an average local tea market demand is 25 thousand tones annually both Mainland and Zanzibar.
# Currently, it is 9.7 tones are produced, therefore we target to cater to 7% of the market that is 2, 590,000 in Dar es Salaam Region.
#
# Zone géographique de l’activité
# Muheza is one of the ten districts of the Tanga Region in Tanzania. It is bordered to the north by Mkinga District, to the east by the Tanga and the Indian Ocean, to the south by the Pangani District and Handeni District, and to the west by the Korogwe District. The administrative capital of the district is Muheza town.
#  According to the 2012 Tanzania National Census, the population of Muheza District was 404,461; depending mainly on small scaling farming largely on tea and spices.
# When it comes to agribusiness in Muheza Tanzania bear substantial responsibilities in both food and cash crops production
#
# Objectifs de croissance et vision à moyen et long terme du marché
# In the next two years will be selling our tea products all over Tanzania, we will increase blending and packaging to reach 4.5 tones annually making more than  $ 150,000/=  revenue generation. Not only that but also expanding our business to neighboring countries like the Democratic Republic of  Congo and Ethiopia.
# We are determined to build Pan African tea and coffee brand, therefore by 2030 will be selling our products across Africa.
#
# En quoi votre solution est elle innovante
# We are challenging and disrupting the status quo by changing the way marginalized groups and excluded communities were left in the stake of the economy by giving them skills, tools, and resources to own the economy.
# Our approach is inclusive, we create a sense of ownership to local communities, creating a market for them as well as facilitating them with productive resources including land and incentives.
# Not only that but also, the final tea products are 100% organic proven to reduce blood glucose levels better for fighting diabetes and allergy.
#
# En quoi est elle duplicable à moindre coût
# Our main goal is to improve lives in remote, impoverished and neglected rural areas by creating improved access to productive resources as well as meaningful jobs.
# Therefore our solution is based on leaving no one behind; it is an inclusive approach to fighting poverty in Tanzania. It is affordable and can be applied anywhere in Africa.
#
# En quoi votre solution rend les villes françaises et africaines plus durables du point de vue environnemental et social
# With no doubt, our solution will make African and French cities more sustainable in the sense that World tea production has increased at an average annual growth rate of 4.4 percent over the past decade to reach 5.812 million tonnes in 2018.
# This significant growth in global output was mainly the result of an Africa’s hugely expanded tea production, which has more than doubled since 2008 to reach 2.609 million tonnes in 2017 – 45 percent of the world’s tea is now coming from Africa. (Source United Nations FAO Inter-Governmental Group (IGG) Tea in May 2018).
# By 2050 around 2.2 billion people could be added to the global population and more than half of that growth will occur in Africa.
# Africa will account for the highest population spurt with an additional 1.3 billion people on the continent, a new UN population report shows.
# Therefore in the next, fifteen to twenty years Africa is will be the largest tea consumer in the World as the population and demand for tea products are largely increasing.
# Hence solution will make African and French cities more sustainable in terms of tea market availability both Africa and Europe.

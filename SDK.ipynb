# %%
import DA_IO

# %%
name = "Première analyse Les 10"
DA_IO.Gspreadsheet().sheet_to_df(name)
# Out:
# Project ID:  web-services-d4-digital-africa
# Service Account Email:  main-d4da@web-services-d4-digital-africa.iam.gserviceaccount.com
#     Civilité (répondant)          Nom          Prénom  \
# 0                   Mrs.     Mandlazi         Beverly
# 1                   Mrs.  Mwakyambiki      Jacqueline
# 2                    Mr.    Chingonzo         Takunda
# 3                    Mr.        Tambo          Joshwa
# 4                   Mrs.       Judith         Bikawei
# ..                   ...          ...             ...
# 154                 Mrs.      VOLWANA       THULISILE
# 155                 Mrs.     NAMITALA        GERTRUDE
# 156                 Mrs.        Mentz         Valerie
# 157                  Mr.       Thlaku          Tshepo
# 158                    M        BALMA  Ange Frédérick
#
#                 E-mail (répondant) Pays d'origine (entreprise)  \
# 0         nunukemandlazi@gmail.com              Afrique du Sud
# ...

# %%
with open('/Users/Shared/digital-africa/web-services-d4-digital-africa-2eb794c55b04.json', 'r') as cred:
        a = cred.readlines()
a[1]
# Out:
# '  "type": "service_account",\n'

# %%
import json

uri = '/Users/Shared/digital-africa/web-services-d4-digital-africa-2eb794c55b04.json' 
def get_schema(uri):
    with open(uri, 'r') as s:
        schema = json.load(s)
    return schema

get_schema(uri)['project_id']
get_schema(uri)['client_email']
# Out:
# 'main-d4da@web-services-d4-digital-africa.iam.gserviceaccount.com'

# %%
import library

from IPython.display import display, HTML
import pandas
import collections
import math
import collections
import re
import nltk
#nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import string
import time
from nltk.corpus import wordnet

import requests
import urllib.parse

from time import time

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups
import numpy as np

# %%
df_filter = library.Filter().X
display(df_filter.head())
display(df_filter.describe(include = 'all'))
df_filter_category  = df_filter[df_filter['categorie'] == 'mobilite']
display(df_filter_category.head())
display(df_filter_category.describe(include = 'all'))
text = library.Transformation().X

subset = df_filter_category.join(text)
kwE = library.Keyword_extraction(X = subset, file = 'stopwords.txt')
kw = kwE.operation()
# Out:
#                                                     categorie age_pers  \
# key_main
# http://seneyakaare.com_ndiaye_diariyata                 sante    35-50
# https://wb.semoa-group.com/_adjamagbo_edem            finance    25-34
# https://talenteum.com/_nicolas_goldstein          technologie    35-50
# http://chapwifi.bj/_adjassa_azimath                     media    25-34
# https://www.facebook.com/TZenSn/_diop_sokhnalaye  agriculture    25-34
#
#                                                   nbr_salarie   ca_2017  \
# key_main
# http://seneyakaare.com_ndiaye_diariyata                     1       0.0
# https://wb.semoa-group.com/_adjamagbo_edem                  4       0.0
# https://talenteum.com/_nicolas_goldstein                  100  400000.0
# http://chapwifi.bj/_adjassa_azimath                         6       NaN
# https://www.facebook.com/TZenSn/_diop_sokhnalaye            4       NaN
#
#                                                   ca_2018  ca_2019
# key_main
# ...

# %%
text_ = kw[['prez_struc_lemm', 'prez_produit_struc_lemm', 'prez_marche_struc_lemm', 'prez_zone_struc_lemm', 'prez_objectif_struc_lemm', 'prez_innovante_struc_lemm', 'prez_duplicable_struc_lemm', 'prez_durable_struc_lemm']].agg(' '.join, axis=1)

# %%
'africa' in ' '.join(text_.values.tolist())
# Out:
# True

# %%
kwE.is_stopword('africa')
# Out:
# True

# %%
print(len([wrd for wrd in ' '.join(text_.values.tolist()).split() if kwE.is_stopword(wrd) is False]))
print(len([wrd for wrd in ' '.join(text_.values.tolist()).split()]))
# Out:
# 37988
# 37988

# %%
'africa' in [wrd for wrd in ' '.join(text_.values.tolist()).split() if kwE.is_stopword(wrd) is False]
# Out:
# False

# %%
kw.head()
# Out:
#                                                    categorie         age_pers  \
# key_main
# https://sourcenets.com/_renson_renson               mobilite            25-34
# https://coliba.ci_kone_yaya                         mobilite            35-50
# http://www.misstaxighana.com_nyador_esenam          mobilite            35-50
# http://mediapressafrica.com/_dounkengzele_brice...  mobilite  Moins de 25 ans
# http://www.safiride.com_erhabor_ikponmwosa          mobilite          Over 50
#
#                                                     nbr_salarie  ca_2017  \
# key_main
# https://sourcenets.com/_renson_renson                         8   2000.0
# https://coliba.ci_kone_yaya                                   6      0.0
# http://www.misstaxighana.com_nyador_esenam                    3      NaN
# http://mediapressafrica.com/_dounkengzele_brice...            5     22.5
# http://www.safiride.com_erhabor_ikponmwosa                   16      NaN
#
# ...

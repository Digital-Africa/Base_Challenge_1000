# %%
import DA_IO

# %%
Gdoc = DA_IO.Gspreadsheet('*Liste BIG 0909')
# Out:
# Project ID:  web-services-d4-digital-africa
# Service Account Email:  main-d4da@web-services-d4-digital-africa.iam.gserviceaccount.com

# %%
X = Gdoc.sheet_to_df()

# %%
Y = DA_IO.Gspreadsheet('Premiere analyse Les 10').sheet_to_df()
# Out:
# Project ID:  web-services-d4-digital-africa
# Service Account Email:  main-d4da@web-services-d4-digital-africa.iam.gserviceaccount.com

# %%
X.keys()
# Out:
# Index(['Pays ', 'Civilité', 'Nom', 'Prénom', 'Nationalité',
#        'Votre langue de travail (plusieurs possibles)',
#        'Le(s) fondateur(s) de la structure est-il (sont-ils) différent(s) du porteur de projet ?',
#        'Nom / Raison sociale de la structure',
#        'Date de création de la structure', 'statut'],
#       dtype='object')

# %%
X['key'] = X["Nom / Raison sociale de la structure"] + ['Nom'] +  X['Prénom']#+ X['Nom / Raison sociale de la structure']

# %%
Y.keys()
# Out:
# Index(['Civilité (répondant)', 'Nom', 'Prénom', 'E-mail (répondant)',
#        'Pays d'origine (entreprise)', 'Pays d'activité (entreprise)',
#        'Age (entreprise)', 'Chiffre d'affaire 2019', 'Croissance 2018-2019',
#        'Obtention d'un prix', 'Investisseurs renseignés', 'Site existant',
#        'Linkedin entreprise existant', 'Catégories', 'Innovant', 'Tech',
#        'Coup de coeur', 'Commentaires', '2ème catégorie pertinente', 'key'],
#       dtype='object')

# %%
Y = Y.set_index('key')
X = X.set_index('key')

# %%
X[['Nationalité','Nom / Raison sociale de la structure','Date de création de la structure','statut']].join(Y)
# Out:
#                               Nationalité  \
# key
# AlgérieNommyriam                  Algérie
# BotswanaNomruth raina            Zimbabwe
# Burkina FasoNomdiloma azize  Burkina Faso
# Burkina FasoNomflorence      Burkina Faso
# Burkina FasoNomkadija        Burkina Faso
# ...                                   ...
# TogoNomkafui koffi                   Togo
# TogoNommessina                     France
# TunisiaNomadel                    Tunisie
# TunisiaNomaymen                   Tunisie
# UgandaNomesteeri                   Uganda
#
#                             Nom / Raison sociale de la structure  \
# key
# AlgérieNommyriam                                           SUNGY
# BotswanaNomruth raina                         EasiMail (Pty) Ltd
# Burkina FasoNomdiloma azize          Association AFRICA ECOLOGIE
# Burkina FasoNomflorence                             Faso Attiéké
# Burkina FasoNomkadija              Farafina Eco Engineering SARL
# ...

# %%
import challenge1000

# %%
raw = challenge1000.Native().ALL
# Out:
# /Volumes/GoogleDrive/My Drive/Open Data Platform/DATA/SCHEMA/star_schema.json
# /Volumes/GoogleDrive/My Drive/Open Data Platform/DATA/SCHEMA/star_schema.json

# %%
#raw[['nom_struc','nom_pers', 'prenom_pers']]
raw['nom_struc'] = raw['nom_struc'].map(lambda x: x.lower())
raw['nom_pers'] = raw['nom_pers'].map(lambda x: x.lower())
raw['prenom_pers'] = raw['prenom_pers'].map(lambda x: x.lower())
raw['key'] = raw[['nom_struc','nom_pers', 'prenom_pers']].agg('_'.join, axis =1)

# %%
X["Nom / Raison sociale de la structure"] = X["Nom / Raison sociale de la structure"].map(lambda x: x.lower())
X['Nom'] = X['Nom'].map(lambda x: x.lower())
X['Prénom'] = X['Prénom'].map(lambda x: x.lower())
X['key'] = X[["Nom / Raison sociale de la structure",'Nom','Prénom']].agg('_'.join, axis = 1)

# %%
raw.set_index('key').join(Y.set_index('key'))[['nom_struc','Prénom']]
# Out:
#                                                                                             nom_struc  \
# key
# "e-llumin8" trading as rant edu (pty) ltd_rantl...          "e-llumin8" trading as rant edu (pty) ltd
# "n-bio solution" est un projet agrobusiness spé...  "n-bio solution" est un projet agrobusiness sp...
# #elementerre_deme_amadou doudou                                                          #elementerre
# (ban-twa-na) craft_mbhamali_lungile                                                (ban-twa-na) craft
# (build beauty body and nature). pour un changem...  (build beauty body and nature). pour un change...
# ...                                                                                               ...
# zozani_dembele_fousseyni                                                                       zozani
# zulu nomad_hlazo_phakamile                                                                 zulu nomad
# ...

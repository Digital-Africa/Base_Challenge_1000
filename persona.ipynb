# %%
import pandas
import collections
import math
import collections
from googletrans import Translator
import re
import nltk
#nltk.download('wordnet')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import string
import time

import requests
import urllib.parse

from time import time

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation
from sklearn.datasets import fetch_20newsgroups

class RefEnv(object):
    """docstring for RefEnv"""
    def __init__(self):
        self.dst = 'Source'
        self.Export_folder = 'Export'
        self.src = '/Users/py3/Google Drive (mohamed.diabakhate@digital-africa.co)/PROJET DATA/DATA/{}'

class Transformation(object):
    """docstring for RefEnv"""
    def __init__(self):
        self.src = RefEnv().src.format('Transformed/df1_clean.csv')
        self.X = pandas.read_csv(self.src).fillna(0)
        #self.export = X.to_csv(RefEnv().src.format('Transformed/prep_df1_clean.csv'))
        self.header = ['cat_struc', 'cat_autre_struc']
        self.header_tr = ['prez_struc', 'prez_produit_struc', 'prez_marche_struc', 'prez_zone_struc', 'prez_objectif_struc', 'prez_innovante_struc', 'prez_duplicable_struc', 'prez_durable_struc'] 

    def categorie_structure(self,cat_struc,cat_autre_struc):
        if cat_struc == "Santé, bien être, et protection sociale" or cat_struc == "Health, well-being and social protection":
            return "sante" 
        if cat_struc == "Fintech":
            return "finance"
        if cat_struc == "Technologies émergentes" or cat_struc == "Emerging technologies":
            return "technologie"
        if cat_struc == "Médias, édition et communication" or cat_struc =="Media, publishing and communication":
            return "media"
        if cat_struc == "Agriculture, territoires ruraux et ressources naturelles" or cat_struc == "Agriculture, rural areas and natural resources":
            return  "agriculture"
        if cat_struc == "Education, formation professionnelle et emploi" or cat_struc =="Education, vocational training and employment":
            return  "education" 
        if cat_struc == "E-commerce, marketing et distribution" or cat_struc == "E-commerce, marketing and distribution":
            return  "ecommerce"
        if cat_struc == "Gouvernement ouvert et transformation sociale" or cat_struc == "Open government and social transformation":
            return  "gouvernement"
        if cat_struc == "Energie" or cat_struc == "Energy":
            return  "energie" 
        if cat_struc == "Territoires intelligents et mobilité" or cat_struc == "Intelligent territories and mobility":
            return  "mobilite"
        if cat_struc == "Industries culturelles et créatives" or cat_struc == "Cultural and creative industries":
            return  "culture"
        if (cat_struc == "Autre (précisez)" or cat_struc == "Other - please specify" or cat_struc == "autre (précisez)"):
            return  'autres'
        if cat_struc != cat_struc:
            return 'non renseigné'
        else:
            return cat_struc
    
    def traductor(self, element):
        key = '9b87800e-c11c-5e98-649b-21d40847e9af'
        text= urllib.parse.quote(element)
        resp = requests.get('https://api.deepl.com/v2/translate?auth_key={}&text={}&target_lang=EN'.format(key, text))
        return resp.json()['translations'][0]['text']

    def lower_case(self, element):
        return element.lower()

    def number_to_text(self, element):
        return re.sub(r'\d+','', element)

    def remove_punctuation(self, element):
        return element.translate(str.maketrans('', '', string.punctuation))

    def remove_whitespaces(self, element):
        return element.strip()

    def preprocesssing(self, element):
        if type(element)==type(''):
            element = self.remove_punctuation(element)
            element = self.number_to_text(element)
            element = self.lower_case(element)    
            #element = self.traductor(element)
            #assert type(element) == type('')
            element = self.remove_whitespaces(element)
            return element
        else:
            return ''
    
    def operation(self):
        self.X = self.X[self.header+self.header_tr]
        self.X['cat_struc'] = self.X.apply(lambda x: self.categorie_structure(x['cat_struc'], x['cat_autre_struc']), axis=1)
        for head in self.header_tr:
            self.X['{}_trad'.format(head)] = self.X[head].apply(self.preprocesssing)
        #self.X.to_csv(RefEnv().src.format('Transformed/prep_df1_clean_trad.csv'))
        return self.X
    
class Keyword_extraction(object):
    def __init__(self,list_stop_word):
        self.categories = ['technologie', 'agriculture', 'sante','education']
        self.X = Transformation().operation()
        self.header_tr = [a for a in self.X.keys().values.tolist() if 'trad' in a]
        self.stop_words = set(stopwords.words('english')).union(set(stopwords.words('french'))).union(set(list_stop_word))
        self.X = self.operation()

    def tokenize_n_stemm(self, element):
        stemmer=  PorterStemmer()
        return ' '.join([stemmer.stem(i) for i in word_tokenize(element) if not i in self.stop_words])
    
    def tokenize_n_lemm(self, element):
        lemmer=  WordNetLemmatizer()
        return ' '.join([lemmer.lemmatize(i) for i in word_tokenize(element) if not i in self.stop_words])
    
    def operation(self):
        for head in self.header_tr:
            self.X['{}_stemm'.format(head)] = self.X[head].apply(self.tokenize_n_stemm)
            self.X['{}_lemm'.format(head)] = self.X[head].apply(self.tokenize_n_lemm)
        return self.X   
    
    def counter(self):
        full_corpus_stemm = []
        for element in [head for head in self.X if 'stemm' in head]:
            full_corpus_stemm = full_corpus_stemm + self.X[element].values.tolist()
        full_corpus_stemm = [item for sublist in full_corpus_stemm for item in sublist]

        full_corpus_lemm = []
        for element in [head for head in self.X if 'lemm' in head]:
            full_corpus_lemm = full_corpus_lemm + self.X[element].values.tolist()
        full_corpus_lemm = [item for sublist in full_corpus_lemm for item in sublist]
        return full_corpus_stemm, full_corpus_lemm 

    def counter_by_categorie(self, categorie):
        full_corpus_stemm = []
        for element in [head for head in self.X if 'stemm' in head]:
            full_corpus_stemm = full_corpus_stemm + self.X[self.X['cat_struc'] == categorie][element].values.tolist()
        full_corpus_stemm = [item for sublist in full_corpus_stemm for item in sublist]

        full_corpus_lemm = []
        for element in [head for head in self.X if 'lemm' in head]:
            full_corpus_lemm = full_corpus_lemm + self.X[self.X['cat_struc'] == categorie][element].values.tolist()
        full_corpus_lemm = [item for sublist in full_corpus_lemm for item in sublist]
        return full_corpus_stemm, full_corpus_lemm
    
    def present_most_common(self, N):
        for categorie in self.categories:
            print(categorie)
            s, l = self.counter_by_categorie(categorie)
            print('stemm')
            print(collections.Counter(s).most_common(N))
            print('lemm')
            print(collections.Counter(l).most_common(N))
            
class LDA(object):
    from time import time

    from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
    from sklearn.decomposition import NMF, LatentDirichletAllocation
    from sklearn.datasets import fetch_20newsgroups

    def __init__(self):
        self.n_samples = 2000
        self.n_features = 1000
        self.n_components = 20
        self.n_top_words = 20

    def print_top_words(self, model, feature_names, n_top_words):
        for topic_idx, topic in enumerate(model.components_):
            message = "Topic #%d: " % topic_idx
            message += " ".join([feature_names[i]
                                 for i in topic.argsort()[:-n_top_words - 1:-1]])
            print(message)
        print()
        
    def perform_lda(self, data_samples):
        t0 = time()
        print("done in %0.3fs." % (time() - t0))

        # Use tf-idf features for NMF.
        print("Extracting tf-idf features for NMF...")
        tfidf_vectorizer = TfidfVectorizer(max_df=0.95, min_df=2,
                                           max_features=self.n_features,
                                           stop_words='english')
        t0 = time()
        tfidf = tfidf_vectorizer.fit_transform(data_samples)
        print("done in %0.3fs." % (time() - t0))

        # Use tf (raw term count) features for LDA.
        print("Extracting tf features for LDA...")
        tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2,
                                        max_features=self.n_features,
                                        stop_words='english')
        t0 = time()
        tf = tf_vectorizer.fit_transform(data_samples)
        print("done in %0.3fs." % (time() - t0))
        print()

        # Fit the NMF model
        print("Fitting the NMF model (Frobenius norm) with tf-idf features, "
              "n_samples=%d and n_features=%d..."
              % (self.n_samples, self.n_features))
        t0 = time()
        nmf = NMF(n_components=self.n_components, random_state=1,
                  alpha=.1, l1_ratio=.5).fit(tfidf)
        print("done in %0.3fs." % (time() - t0))

        print("\nTopics in NMF model (Frobenius norm):")
        tfidf_feature_names = tfidf_vectorizer.get_feature_names()
        self.print_top_words(nmf, tfidf_feature_names, self.n_top_words)

        # Fit the NMF model
        print("Fitting the NMF model (generalized Kullback-Leibler divergence) with "
              "tf-idf features, n_samples=%d and n_features=%d..."
              % (self.n_samples, self.n_features))
        t0 = time()
        nmf = NMF(n_components=self.n_components, random_state=1,
                  beta_loss='kullback-leibler', solver='mu', max_iter=1000, alpha=.1,
                  l1_ratio=.5).fit(tfidf)
        print("done in %0.3fs." % (time() - t0))

        print("\nTopics in NMF model (generalized Kullback-Leibler divergence):")
        tfidf_feature_names = tfidf_vectorizer.get_feature_names()
        self.print_top_words(nmf, tfidf_feature_names, self.n_top_words)

        print("Fitting LDA models with tf features, "
              "n_samples=%d and n_features=%d..."
              % (self.n_samples, self.n_features))
        lda = LatentDirichletAllocation(n_components=self.n_components, max_iter=5,
                                        learning_method='online',
                                        learning_offset=50.,
                                        random_state=0)
        t0 = time()
        lda.fit(tf)
        print("done in %0.3fs." % (time() - t0))

        print("\nTopics in LDA model:")
        tf_feature_names = tf_vectorizer.get_feature_names()
        self.print_top_words(lda, tf_feature_names, self.n_top_words)

        return lda, tf_feature_names

# %%
X = Transformation().X

# %%
X['nbr_salarie'] = X[['empl_h_struc', 'empl_f_struc']].agg(sum, axis=1)
X['ca_2019'] = X[['ca_2019_trim1', 'ca_2019_trim2', 'ca_2019_trim3']].agg(sum, axis=1)

# %%
persona = {'age_pers':X['age_pers'] == '25-34', 
           'nbr_salarie':X['nbr_salarie'].isin(range(0,10)),
           '1_ca': (X['ca_2017']>0) | (X['ca_2018']>0)|(X['ca_2019']>0),
           'ca2019':(X['ca_2019']>0),
           'ca': (X['ca_2017']>0) & (X['ca_2018']>0)&(X['ca_2019']>0) }

# %%
X = X[(persona['age_pers'])&(persona['nbr_salarie'])&(persona['ca'])]

# %%
fileName = '/Volumes/GoogleDrive/My Drive/PROJET DATA/SCRIPT/analyse Startup/mo/notebooks/stopwords.txt'
stopword_file = open(fileName, 'r')
list_stop_word = [line.split(',') for line in stopword_file.readlines()][0]
kwrds_xtrct = Keyword_extraction(list_stop_word)
data_samples = kwrds_xtrct.X[['prez_struc_trad_lemm', 'prez_produit_struc_trad_lemm', 'prez_marche_struc_trad_lemm', 'prez_zone_struc_trad_lemm', 'prez_objectif_struc_trad_lemm', 'prez_innovante_struc_trad_lemm', 'prez_duplicable_struc_trad_lemm', 'prez_durable_struc_trad_lemm']].agg(' '.join, axis=1)

# %%
method = LDA()
_,_ = method.perform_lda(data_samples)
# Out:
# done in 0.000s.
# Extracting tf-idf features for NMF...
# done in 1.432s.
# Extracting tf features for LDA...
# done in 1.388s.
#
# Fitting the NMF model (Frobenius norm) with tf-idf features, n_samples=2000 and n_features=1000...
# done in 1.594s.
#
# Topics in NMF model (Frobenius norm):
# Topic #0: plateforme service ligne mobile application web solution livraison pay utilisateurs client site numérique temp internet vente paiement africains communication professionnels
# Topic #1: city service african year solution technology country market company need cost time area make work use provide client government management
# Topic #2: produits locaux transformation qualité bio naturels vente consommateurs locale prix sans distribution production base gamme marque consommation marchés lentreprise fabrication
# Topic #3: farmer food farm farming agricultural produce agriculture crop smallholder market organic input vegetable urban chain rural feed land fish agribusiness
# Topic #4: déchets plastique recyclage collecte ménages gestion tonne lenvironnement environnement matière pollution valorisation bois matières traitement solution emplois première transformation kinshasa
# Topic #5: waste plastic recycling material management collection environment environmental household clean sustainable community bag organic used pollution use green process city
# Topic #6: formation professionnelle centre étudiants programme numérique compétences entrepreneur métiers emploi professionnels accompagnement cours digital développement communication conseil éducation informatique jeunesse
# Topic #7: energy solar power renewable electricity clean access rural home household community cooking affordable fuel cost sustainable solution emission carbon use
# Topic #8: community woman skill training young program entrepreneur job entrepreneurship girl sustainable youth organization opportunity social support life child create society
# Topic #9: santé patient prise malady population charge données accès mali système bonne centre améliorer information ca vie traitement bio structure professionnels
# Topic #10: health patient healthcare medical care hospital disease facility child provider access service app worker life quality information user cost need
# Topic #11: product market food year produce material consumer customer quality production sale cost brand country make high raw price sell increase
# Topic #12: water fish plant clean supply used farming use sustainable smart vegetable technology feed control natural solution locally area saving community
# Topic #13: construction matériaux terre écologique bois travaux maison ufd moins building fabrication espaces conception locaux material réduire production faible infrastructure durables
# Topic #14: student school education child learning teacher content parent educational university book course year learn science language primary training program skill
# Topic #15: transport bus taxi public transportation vehicle driver application urbain route temp solution paiement mode service système road madagascar app sécurité
# Topic #16: platform user online digital business payment access financial app mobile market service money bank customer african data million year small
# Topic #17: développement solution projets pay durable gestion population création cameroun vie mise structure secteur objectif environnement économique zone toutes enfants social
# Topic #18: production agricoles agricole fruit producteurs agriculteurs légumes sol agriculture transformation alimentaire culture tonne produire lagriculture aliment bio commercialisation technique bénin
# Topic #19: solaire solaires énergie kit électricité installation énergies gaz zone système ménages accès consommation solution équipements eau systèmes maintenance rurales village
#
# Fitting the NMF model (generalized Kullback-Leibler divergence) with tf-idf features, n_samples=2000 and n_features=1000...
# done in 12.417s.
#
# Topics in NMF model (generalized Kullback-Leibler divergence):
# Topic #0: solution pay client moyen objectif peut long dont avoir également point sans où cela moindre cible donc besoin plusieurs africaines
# Topic #1: african market country need year make target city solution able product cost use access provide area new increase platform create
# Topic #2: production produits bio transformation base contre fruit alimentaire produire agricoles locaux commercialisation aliment consommation consommateurs qualité distribution locale naturels ménages
# Topic #3: plateforme service application web ligne numérique mobile utilisateurs accès internet temp digitale informatique avoir communication site sans technologie information données
# Topic #4: déchets durable environnement contre lenvironnement solution construction développement duplicable recyclage domaine gestion protection durables matière innovante collecte lutte plastique fabrication
# Topic #5: waste material environment environmental climate green change industry clean alternative cost process plastic pollution carbon household city used gas water
# Topic #6: formation centre association développement mission culture créer projets national entrepreneur promotion programme ressources plan international action vie organisation local accompagnement
# Topic #7: energy cost solar commercial rural electricity operation efficient power demand infrastructure customer access data smart currently design based year clean
# Topic #8: education community activity skill program organization school child training group impact support social entrepreneur economic change focus life knowledge young
# Topic #9: accès santé système zone population milieu amélioration temp eau vie améliorer gestion équipements technologie utilisation besoins impact effet énergie condition
# Topic #10: information digital communication service institution management active centre action web place agent organisation base inclusion budget technology national promotion collection
# Topic #11: product market health production year produce make country cost quality available material price high objective life target consumer brand child
# Topic #12: solution technology application digital mobile web innovation intelligence communication simple data information internet process place smart learning marketing public software
# Topic #13: client long local service construction international company design mission building area city general medium public concept art standard house structure
# Topic #14: access accessible long student mobile parent pay user education online school service platform university provide device test feature billion vision
# Topic #15: service client transport place public restaurant application charge location point course type taxi route bus plan transportation hotel district centre
# Topic #16: pay cible africain africaine france africains continent million base long application europe entre structure culture diaspora vision lafrique toute divoire
# Topic #17: développement mise projets acteurs économique développer entre gestion secteur création service financement économie locale locaux besoins modèle œuvre croissance valeur
# Topic #18: congo agricole production agricoles vente site commerce grand actuellement lagriculture mois deux république dune vendre général producteurs déjà million marchés
# Topic #19: accessible accès produits vente africain social solaire distribution domicile burkina africaine faso économique grande ménages partir consommation commerce modèle fin
#
# Fitting LDA models with tf features, n_samples=2000 and n_features=1000...
# done in 11.996s.
#
# Topics in LDA model:
# Topic #0: transport congo bus kinshasa taxi rdc province uf république route driver transportation public mode pay vehicle solution parent dont urbain
# Topic #1: solution service plateforme application mobile temp pay web internet client numérique information accès santé communication données système gestion site utilisateurs
# Topic #2: start produits service contre sénégal voulons type maintenance locale travailler production personne moringa plusieurs transformation mois temp emplois lutter grandes
# Topic #3: construction plastic matériaux recycling waste bag building material infrastructure house solution terre durable site industry service diaspora client housing build
# Topic #4: fish feed year waste production material service use month raw food price product platform country solution student option general offer
# Topic #5: ufd uffc guinée expert république principal base national client book mission service inclusive unité capital centre job rural social jeunesse
# Topic #6: production agricoles produits agricole producteurs agriculteurs agriculture fruit zone solaire culture alimentaire énergie eau solaires technique solution légumes miel kit
# Topic #7: service solution platform user data technology mobile digital access market health app management financial year provide application information time country
# Topic #8: waste product production community city sustainable material year market use local cost fish solution environment country make produce area used
# Topic #9: product market year customer service solution city african sale make consumer online cost country small time platform target food need
# Topic #10: rwanda moringa green smart city mali world madagascar million transformation place transport east region produits dont consiste restaurant accessible international
# Topic #11: grandes minimum software skill space service creative solution affordable type maintenance entrepreneur community new want design able mobile owner temp
# Topic #12: energy water solar power solution electricity clean technology renewable cost rural access home community fuel area smart city sustainable use
# Topic #13: produits déchets solution production pay qualité plastique client sans transformation moins contre base prix également vie ménages santé donc service
# Topic #14: operation farming fish supply term mobile community long local supplier sustainable employment money formation efficiency cost increase service developed water
# Topic #15: school community student education skill training year african child woman solution work young city social country local program sustainable learning
# Topic #16: développement formation projets service gestion solution pay programme durable centre mise création place secteur entrepreneur développer ressources travail acteurs technique
# Topic #17: solution matériaux service conception structure santé transport client make year population pay environment construction communication rural product supplier mali mise
# Topic #18: ligne plateforme livraison pay vente artisan africains paiement service produits carte client tchad ecommerce mobile commerce niger étudiants africain mode
# Topic #19: farmer food farm agricultural market produce agriculture farming crop production urban land value rural organic vegetable chain supply feed smallholder
